# %% [markdown]
# # DMRG : Modern MPS (Matrix product state) version

# %% [markdown]
# Edited by [Min Long](https://quantummc.xyz/members/min-long/) in October 2023.
#
# Revised by [ZYM](https://quantummc.xyz/members/ziyang-meng/) in February 2026.
#
# This is a notebook on modern DMRG algorithm written in Matrix product states(MPS) formalism. The code shown in this notebook is adapted from Internet and revised by Min Long.
#
# For further information, one can read the reference articles of this notebook by Schollwoeck [arXiv:1008.3477](https://arxiv.org/abs/1008.3477v2).

# %%
import numpy as np
import scipy
import scipy.sparse.linalg
import scipy.sparse as sparse
import math
import matplotlib.pyplot as plt
import numpy.linalg as npla

# %% [markdown]
# ## Work flow explaination
#
# Similar as the block enlargement method, we are dealing with a Hamilonian with form
# $$
# H = H^L_{eff} \otimes H_i \otimes H^R_{eff}
# $$
# where $H^L_{eff}$ is the Hamiltonian of the left chain written in the basis of low energy eigenstate, this is achieved by contracting all the left tensors, as shown in the figure, like wise for $H^R_{eff}$.
#
#
# ![Alt text](https://github.com/DavidGoing/DMRG/blob/main/figures/workflow.png?raw=true)
#
# After the diagonalization, we perform SVD to move to next site.
#
#
# ## Explaination of the variables
# - W : Matrix product operator form of the Heisenberg chain (at all the $H_i$).
# - A : Left canonical state.
# - B : Right canonical state.
# - E : Left vacum state to store the information of contraction from left at each step ($H^L_{eff}$ in each step, and update every time when SVD is performed).
# - F : Right vacuum state with same use ($H^R_{eff}$ in each step, and update every time when SVD is performed).

# %%
## initial E and F matrices for the left and right vacuum states
def initial_E(W):
    E = np.zeros((W.shape[0], 1, 1))
    E[0] = 1
    return E


def initial_F(W):
    F = np.zeros((W.shape[1], 1, 1))
    F[-1] = 1
    return F

# %% [markdown]
# ### Contraction function

# %% [markdown]
# Basically, the contraction is performed step be step. At nth site, the contraction from left to right is performed as showned below:
#
# ![Alt text](https://github.com/DavidGoing/DMRG/blob/main/figures/contraction.png?raw=true)
#
# The contraction from right to left is performed as showned below:
#
# ![Alt text](https://github.com/DavidGoing/DMRG/blob/main/figures/contraction_r_l.png?raw=true)

# %%
def contract_from_left(W, A, E, B):
    # the einsum function doesn't appear to optimize the contractions properly,
    # so we split it into individual summations in the optimal order
    # return np.einsum("abst,sij,aik,tkl->bjl",W,A,E,B, optimize=True)
    Temp = np.einsum("sij,aik->sajk", A, E)
    Temp = np.einsum("sajk,abst->tbjk", Temp, W)
    return np.einsum("tbjk,tkl->bjl", Temp, B)

def contract_from_right(W, A, F, B):
    # the einsum function doesn't appear to optimize the contractions properly,
    # so we split it into individual summations in the optimal order
    # return np.einsum("abst,sij,bjl,tkl->aik",W,A,F,B, optimize=True)
    Temp = np.einsum("sij,bjl->sbil", A, F)
    Temp = np.einsum("sbil,abst->tail", Temp, W)
    return np.einsum("tail,tkl->aik", Temp, B)

## "Can you draw the from right by hand" ?

# construct the F-matrices for all sites except the first
def construct_F(Alist, MPO, Blist):
    F = [initial_F(MPO[-1])]

    for i in range(len(MPO) - 1, 0, -1):
        F.append(contract_from_right(MPO[i], Alist[i], F[-1], Blist[i]))
    return F


def construct_E(Alist, MPO, Blist):
    return [initial_E(MPO[0])]

def Expectation(AList, MPO, BList):
    E = [[[1]]]
    for i in range(0, len(MPO)):
        E = contract_from_left(MPO[i], AList[i], E, BList[i])
    return E[0][0][0]

# %% [markdown]
# #  A 5-site example
#
# ## From right to left (Recursive coding)
# ### 1. Setup and Initialization
# Before starting the right-to-left sweep, we define our chain of 5 sites (indices 0, 1, 2, 3, 4).
# The list `F` is initialized with the 'Right Vacuum' boundary.
#
# * MPO Tensors: [W0, W1, W2, W3, W4]
# * Initial State: F = [initial_F]
#
# ---
#
# ### 2. The `construct_F` Loop Trace
# Loop: `for i in range(4, 0, -1):`
# In each step, `F[-1]` is contracted with site `i` to grow the environment.
#
#
# | Iteration | Site (i) | Operation (using F[-1]) | Physical Content | F List State |
# | :--- | :--- | :--- | :--- | :--- |
# | Start | — | — | Right Vacuum | [F_vac] |
# | Step 1 | 4 | Contract(W4, F_vac) | Site 4 | [F_vac, F_4] |
# | Step 2 | 3 | Contract(W3, F_4) | Sites 3 + 4 | [F_vac, F_4, F_34] |
# | Step 3 | 2 | Contract(W2, F_34) | Sites 2 + 3 + 4 | [F_vac, F_4, F_34, F_234] |
# | Step 4 | 1 | Contract(W1, F_234) | Sites 1 + 2 + 3 + 4 | [F_vac, F_4, F_34, F_234, F_1234] |
#
# ---
#
# <br>
#
# ## From left to right
# ### 1. Setup and Initialization (Left-to-Right)
# We define our chain of 5 sites (indices 0, 1, 2, 3, 4). The list `E` is initialized
# with the 'Left Vacuum' boundary, which represents the vacuum state to the left of site 0.
#
# * MPO Tensors: [W0, W1, W2, W3, W4]
# * Initial State: E = [initial_E]
#
# ---
#
# ### 2. The `construct_E` Loop Trace
# Loop: `for i in range(0, 4):`
# In each step, `E[-1]` (the existing left wall) is contracted with site `i`
# to grow the environment for the next site.
#
#
# | Iteration | Site (i) | Operation (using E[-1]) | Physical Content | E List State |
# | :--- | :--- | :--- | :--- | :--- |
# | Start | — | — | Left Vacuum | [E_vac] |
# | Step 1 | 0 | Contract(W0, E_vac) | Site 0 | [E_vac, E_0] |
# | Step 2 | 1 | Contract(W1, E_0) | Sites 0 + 1 | [E_vac, E_0, E_01] |
# | Step 3 | 2 | Contract(W2, E_01) | Sites 0 + 1 + 2 | [E_vac, E_0, E_01, E_012] |
# | Step 4 | 3 | Contract(W3, E_012) | Sites 0 + 1 + 2 + 3 | [E_vac, E_0, E_01, E_012, E_0123] |
#
# ---

# %% [markdown]
# ### Coarse graining and truncation function
#
# To perform 2-site DMRG, we need to do coarse graining for states and operators.
#
# For two site state, two site MPS or product of MPS, the idea of doing coarse graining is similar, we just view two bond at the same direction as one bond (with larger index), as illustrated in the figure below
#
# ![image.png](https://github.com/DavidGoing/DMRG/blob/main/figures/coarse_graining.png?raw=true)

# %%
# 2-1 coarse-graining of two site MPO into one site
def coarse_grain_MPO(W, X):
    return np.reshape(np.einsum("abst,bcuv->acsutv", W, X),
                      [W.shape[0], X.shape[1],
                       W.shape[2] * X.shape[2],
                       W.shape[3] * X.shape[3]])

def product_W(W1, W2):
    return np.reshape(np.einsum("abst,cdtu->acbdsu", W1, W2), [W1.shape[0] * W2.shape[0],
                                                               W1.shape[1] * W2.shape[1],
                                                               W1.shape[2], W2.shape[3]])

def product_MPO(M1, M2):
    assert len(M1) == len(M2)
    Result = []
    for i in range(0, len(M1)):
        Result.append(product_W(M1[i], M2[i]))
    return Result

# 2-1 coarse-graining of two-site MPS into one site
def coarse_grain_MPS(A, B):
    return np.reshape(np.einsum("sij,tjk->stik", A, B),
                      [A.shape[0] * B.shape[0], A.shape[1], B.shape[2]])

#   Fine grain
#
#           (d1 * d2)
#               |
#    ---(χL)---[ A ]---(χR)---

#          (d1)     (d2)          <-- Physical legs split
#           |        |
#    ---(χL)---[ Θ ]---(χR)---    <-- Indices grouped as (0, 2) and (1, 3)

#         (d1)                (d2)
#           |                   |
#  ---(χL)[ U ]---(S)---(S)---[ V ](χR)---


def fine_grain_MPS(A, dims):
    assert A.shape[0] == dims[0] * dims[1]
    Theta = np.transpose(np.reshape(A, dims + [A.shape[1], A.shape[2]]),
                         (0, 2, 1, 3))
    M = np.reshape(Theta, (dims[0] * A.shape[1], dims[1] * A.shape[2]))
    U, S, V = np.linalg.svd(M, full_matrices=0)
    U = np.reshape(U, (dims[0], A.shape[1], -1))
    V = np.transpose(np.reshape(V, (-1, dims[1], A.shape[2])), (1, 0, 2))
    # assert U is left-orthogonal
    # assert V is right-orthogonal
    # print(np.dot(V[0],np.transpose(V[0])) + np.dot(V[1],np.transpose(V[1])))
    return U, S, V

def truncate_MPS(U, S, V, m):
    m = min(len(S), m)
    trunc = np.sum(S[m:])
    S = S[0:m] / np.sum(S[0:m]**2)
    U = U[:, :, 0:m]
    V = V[:, 0:m, :]
    return U, S, V, trunc, m

# %% [markdown]
# ### Work flow : Procedure of DMRG
#
# Define the Hamiltonian based on the transformation of the vector instead of the matrix elements. It is a common way to define a large spase matrix. Then diagonalize the matrix using Lancoz method.
#
# ![image.png](https://github.com/DavidGoing/DMRG/blob/main/figures/workflow.png?raw=true)
#
# From the diagram expression of the Hamiltonain, we see that this Hamiltonian transform tensors.

# %%
class HamiltonianMultiply(sparse.linalg.LinearOperator):
    def __init__(self, E, W, F):
        self.E = E
        self.W = W
        self.F = F
        self.dtype = np.dtype('d')
        self.req_shape = [W.shape[2], E.shape[1], F.shape[1]]
        # self.req_shape = [W.shape[2], E.shape[1], F.shape[2]] ORIGINAL VERSION
        self.size = self.req_shape[0] * self.req_shape[1] * self.req_shape[2]
        self.shape = [self.size, self.size]

    def _matvec(self, A):
        # the einsum function doesn't appear to optimize the contractions properly,
        # so we split it into individual summations in the optimal order
        # R = np.einsum("aij,sik,abst,bkl->tjl",self.E,np.reshape(A, self.req_shape),
        #              self.W,self.F, optimize=True)
        R = np.einsum("aij,sik->ajsk", self.E, np.reshape(A, self.req_shape))
        R = np.einsum("ajsk,abst->bjtk", R, self.W)
        R = np.einsum("bjtk,bkl->tjl", R, self.F)
        return np.reshape(R, -1)


## optimize a single site given the MPO matrix W, and tensors E,F
def optimize_site(A, W, E, F):
    H = HamiltonianMultiply(E, W, F)
    # we choose tol=1E-8 here, which is OK for small calculations.
    # to bemore robust, we should take the tol -> 0 towards the end
    # of the calculation.
    E, V = sparse.linalg.eigsh(H, 1, v0=A, which='SA', tol=1E-8)
    return (E[0], np.reshape(V[:, 0], H.req_shape))


def optimize_two_sites(A, B, W1, W2, E, F, m, dir):
    W = coarse_grain_MPO(W1, W2)
    AA = coarse_grain_MPS(A, B)
    H = HamiltonianMultiply(E, W, F)
    E, V = sparse.linalg.eigsh(H, 1, v0=AA, which='SA')
    AA = np.reshape(V[:, 0], H.req_shape)
    A, S, B = fine_grain_MPS(AA, [A.shape[0], B.shape[0]])
    A, S, B, trunc, m = truncate_MPS(A, S, B, m)
    if (dir == 'right'):
        B = np.einsum("ij,sjk->sik", np.diag(S), B)
    else:
        assert dir == 'left'
        A = np.einsum("sij,jk->sik", A, np.diag(S))
    return E[0], A, B, trunc, m


def two_site_dmrg(MPS, MPO, m, sweeps):
    E = construct_E(MPS, MPO, MPS)
    F = construct_F(MPS, MPO, MPS)
    F.pop()
    for sweep in range(0, int(sweeps / 2)):
        for i in range(0, len(MPS) - 2):
            Energy, MPS[i], MPS[i + 1], trunc, states = optimize_two_sites(MPS[i], MPS[i + 1],
                                                                           MPO[i], MPO[i + 1],
                                                                           E[-1], F[-1], m, 'right')
            print("Sweep {:} Sites {:},{:}    Energy {:16.12f}    States {:4} Truncation {:16.12f}"
                  .format(sweep * 2, i, i + 1, Energy, states, trunc))
            E.append(contract_from_left(MPO[i], MPS[i], E[-1], MPS[i]))
            F.pop();
        for i in range(len(MPS) - 2, 0, -1):
            Energy, MPS[i], MPS[i + 1], trunc, states = optimize_two_sites(MPS[i], MPS[i + 1],
                                                                           MPO[i], MPO[i + 1],
                                                                           E[-1], F[-1], m, 'left')
            print("Sweep {} Sites {},{}    Energy {:16.12f}    States {:4} Truncation {:16.12f}"
                  .format(sweep * 2 + 1, i, i + 1, Energy, states, trunc))
            F.append(contract_from_right(MPO[i + 1], MPS[i + 1], F[-1], MPS[i + 1]))
            E.pop();
    return MPS

# %%
d = 3  # local bond dimension
N = 20  # number of sites
D = 20 # virtue bond dimension

InitialA1 = np.zeros((d, 1, 1))
InitialA1[0, 0, 0] = 1
InitialA2 = np.zeros((d, 1, 1))
InitialA2[2, 0, 0] = 1

## initial state |01010101>
MPS = [InitialA1, InitialA2] * int(N / 2)

MPS[-1] = InitialA1

I = np.identity(d)
Z = np.zeros((d, d))
Sz = np.zeros((d, d))
Sp = np.zeros((d, d))
Sm = np.zeros((d, d))

sz_lsit = []
if d%2 == 0:
    print('Half integer Spin')
    step = 0.5
    for i in range(d//2):
        sz_lsit.append((i+1)*step)
        sz_lsit.append(-(i+1)*step)
    sz_lsit = sorted(sz_lsit)
else:
    print('Integer Spin')
    step = 1
    sz_lsit.append(0)
    for i in range(d//2):
        sz_lsit.append((i+1)*step)
        sz_lsit.append(-(i+1)*step)
    sz_lsit = sorted(sz_lsit)
# print('Spin values: {}'.format(sz_lsit))

Sz = np.diag(sz_lsit)
Sz = Sz.astype('float64') 
for i in range(d-1):
    Sp[i+1,i] = np.sqrt(2-sz_lsit[i]*(sz_lsit[i]+1)) 
for i in range(d-1):
    Sm[i,i+1] = np.sqrt(2-sz_lsit[i]*(sz_lsit[i]+1)) 
# print('Spin chain with total Spin: {}'.format((d-1)/2))
print('Sz matrix form: \n =============')
print(Sz)
print('S+ matrix form: \n =============')
print(Sp)
print('S- matrix form: \n =============')
print(Sm)

## Hamiltonian MPO
W = np.array([[I, Sz, 0.5 * Sp, 0.5 * Sm, Z],
              [Z, Z, Z, Z, Sz],
              [Z, Z, Z, Z, Sm],
              [Z, Z, Z, Z, Sp],
              [Z, Z, Z, Z, I]])

Wfirst = np.array([[I, Sz, 0.5 * Sp, 0.5 * Sm, Z]])

Wlast = np.array([[Z], [Sz], [Sm], [Sp], [I]])

# the complete MPO
MPO = [Wfirst] + ([W] * (N - 2)) + [Wlast]

# 8 sweeps with m=10 states
HamSquared = product_MPO(MPO, MPO)

Gs = two_site_dmrg(MPS, MPO, D, 8)

Energy = Expectation(Gs, MPO, Gs)
print("Final energy expectation value {}".format(Energy))

H2 = Expectation(Gs, HamSquared, Gs)
print("variance = {:16.12f}".format(H2 - Energy * Energy))
# Out:
# Integer Spin
# Sz matrix form:
#  =============
# [[-1.  0.  0.]
#  [ 0.  0.  0.]
#  [ 0.  0.  1.]]
# S+ matrix form:
#  =============
# [[0.         0.         0.        ]
#  [1.41421356 0.         0.        ]
#  [0.         1.41421356 0.        ]]
# S- matrix form:
#  =============
# [[0.         1.41421356 0.        ]
#  [0.         0.         1.41421356]
#  [0.         0.         0.        ]]
# Sweep 0 Sites 0,1    Energy -17.481194304092    States    3 Truncation   0.000000000000
# Sweep 0 Sites 1,2    Energy -17.827550196615    States    3 Truncation   0.000000000000
# Sweep 0 Sites 2,3    Energy -18.203481362554    States    3 Truncation   0.000000000000
# Sweep 0 Sites 3,4    Energy -18.567121450138    States    3 Truncation   0.000000000000
# Sweep 0 Sites 4,5    Energy -18.932138072781    States    3 Truncation   0.000000000000
# Sweep 0 Sites 5,6    Energy -19.295992885665    States    3 Truncation   0.000000000000
# Sweep 0 Sites 6,7    Energy -19.659816720597    States    3 Truncation   0.000000000000
# Sweep 0 Sites 7,8    Energy -20.023503340587    States    3 Truncation   0.000000000000
# Sweep 0 Sites 8,9    Energy -20.387163904761    States    3 Truncation   0.000000000000
# Sweep 0 Sites 9,10    Energy -20.750804560921    States    3 Truncation   0.000000000000
# Sweep 0 Sites 10,11    Energy -21.114438977516    States    3 Truncation   0.000000000000
# Sweep 0 Sites 11,12    Energy -21.478070101678    States    3 Truncation   0.000000000000
# Sweep 0 Sites 12,13    Energy -21.841699974205    States    3 Truncation   0.000000000000
# Sweep 0 Sites 13,14    Energy -22.205329266131    States    3 Truncation   0.000000000000
# Sweep 0 Sites 14,15    Energy -22.568958320115    States    3 Truncation   0.000000000000
# Sweep 0 Sites 15,16    Energy -22.932587268884    States    3 Truncation   0.000000000000
# Sweep 0 Sites 16,17    Energy -23.296216173268    States    3 Truncation   0.000000000000
# Sweep 0 Sites 17,18    Energy -25.010199144930    States    3 Truncation   0.000000000000
# Sweep 1 Sites 18,19    Energy -26.073335951519    States    3 Truncation   0.000000000000
# Sweep 1 Sites 17,18    Energy -26.256374422087    States    9 Truncation   0.000000000000
# Sweep 1 Sites 16,17    Energy -26.274314282753    States    9 Truncation   0.000000000000
# Sweep 1 Sites 15,16    Energy -26.305880931494    States    9 Truncation   0.000000000000
# Sweep 1 Sites 14,15    Energy -26.331166977099    States    9 Truncation   0.000000000000
# Sweep 1 Sites 13,14    Energy -26.360994625064    States    9 Truncation   0.000000000000
# Sweep 1 Sites 12,13    Energy -26.389622231715    States    9 Truncation   0.000000000000
# Sweep 1 Sites 11,12    Energy -26.419925807535    States    9 Truncation   0.000000000000
# Sweep 1 Sites 10,11    Energy -26.450261031682    States    9 Truncation   0.000000000000
# Sweep 1 Sites 9,10    Energy -26.481333746274    States    9 Truncation   0.000000000000
# Sweep 1 Sites 8,9    Energy -26.512651747221    States    9 Truncation   0.000000000000
# Sweep 1 Sites 7,8    Energy -26.544387370762    States    9 Truncation   0.000000000000
# Sweep 1 Sites 6,7    Energy -26.576371302194    States    9 Truncation   0.000000000000
# Sweep 1 Sites 5,6    Energy -26.608874689643    States    9 Truncation   0.000000000000
# Sweep 1 Sites 4,5    Energy -26.641441605689    States    9 Truncation   0.000000000000
# Sweep 1 Sites 3,4    Energy -26.676935038738    States    9 Truncation   0.000000000000
# Sweep 1 Sites 2,3    Energy -26.707819656799    States    9 Truncation   0.000000000000
# Sweep 1 Sites 1,2    Energy -26.778504825024    States    9 Truncation   0.000000000000
# Sweep 2 Sites 0,1    Energy -26.778504825024    States    3 Truncation   0.000000000000
# Sweep 2 Sites 1,2    Energy -26.778504825023    States    9 Truncation   0.000000000000
# Sweep 2 Sites 2,3    Energy -26.782774887228    States   20 Truncation   0.000362128525
# Sweep 2 Sites 3,4    Energy -26.783622649994    States   20 Truncation   0.000259036300
# Sweep 2 Sites 4,5    Energy -26.787267885062    States   20 Truncation   0.000517831656
# Sweep 2 Sites 5,6    Energy -26.789157199845    States   20 Truncation   0.000371300984
# Sweep 2 Sites 6,7    Energy -26.792497806692    States   20 Truncation   0.000531428805
# Sweep 2 Sites 7,8    Energy -26.795111555462    States   20 Truncation   0.000376861563
# Sweep 2 Sites 8,9    Energy -26.798427287167    States   20 Truncation   0.000482492629
# Sweep 2 Sites 9,10    Energy -26.801438893665    States   20 Truncation   0.000375629322
# Sweep 2 Sites 10,11    Energy -26.804789588287    States   20 Truncation   0.000442256076
# Sweep 2 Sites 11,12    Energy -26.807866363835    States   20 Truncation   0.000361487920
# Sweep 2 Sites 12,13    Energy -26.811220647907    States   20 Truncation   0.000458480884
# Sweep 2 Sites 13,14    Energy -26.813903495602    States   20 Truncation   0.000320542516
# Sweep 2 Sites 14,15    Energy -26.817662887617    States   20 Truncation   0.000596075253
# Sweep 2 Sites 15,16    Energy -26.819204682019    States   20 Truncation   0.000244263093
# Sweep 2 Sites 16,17    Energy -26.826642411469    States   20 Truncation   0.000768011323
# Sweep 2 Sites 17,18    Energy -26.826641304491    States    9 Truncation   0.000000000000
# Sweep 3 Sites 18,19    Energy -26.826641304491    States    3 Truncation   0.000000000000
# Sweep 3 Sites 17,18    Energy -26.826641304491    States    9 Truncation   0.000000000000
# Sweep 3 Sites 16,17    Energy -26.826642411469    States   20 Truncation   0.000768011323
# Sweep 3 Sites 15,16    Energy -26.826821207474    States   20 Truncation   0.003462437744
# Sweep 3 Sites 14,15    Energy -26.826827142883    States   20 Truncation   0.003477761407
# Sweep 3 Sites 13,14    Energy -26.827035444904    States   20 Truncation   0.004928237251
# Sweep 3 Sites 12,13    Energy -26.827048689265    States   20 Truncation   0.004635192753
# Sweep 3 Sites 11,12    Energy -26.827210791642    States   20 Truncation   0.005651576054
# Sweep 3 Sites 10,11    Energy -26.827226150309    States   20 Truncation   0.005177512607
# Sweep 3 Sites 9,10    Energy -26.827386230418    States   20 Truncation   0.006133295895
# Sweep 3 Sites 8,9    Energy -26.827403003513    States   20 Truncation   0.005467272969
# Sweep 3 Sites 7,8    Energy -26.827647751942    States   20 Truncation   0.006504993308
# Sweep 3 Sites 6,7    Energy -26.827664963333    States   20 Truncation   0.005486677496
# Sweep 3 Sites 5,6    Energy -26.828085469105    States   20 Truncation   0.006455687125
# Sweep 3 Sites 4,5    Energy -26.828098915745    States   20 Truncation   0.004947896851
# Sweep 3 Sites 3,4    Energy -26.828370462355    States   20 Truncation   0.004656461572
# Sweep 3 Sites 2,3    Energy -26.828362187143    States   20 Truncation   0.001173998217
# Sweep 3 Sites 1,2    Energy -26.828360039559    States    9 Truncation   0.000000000000
# Sweep 4 Sites 0,1    Energy -26.828360039559    States    3 Truncation   0.000000000000
# Sweep 4 Sites 1,2    Energy -26.828360039559    States    9 Truncation   0.000000000000
# Sweep 4 Sites 2,3    Energy -26.828362187143    States   20 Truncation   0.001173998217
# Sweep 4 Sites 3,4    Energy -26.828373492229    States   20 Truncation   0.004698965100
# Sweep 4 Sites 4,5    Energy -26.828377405459    States   20 Truncation   0.005924157262
# Sweep 4 Sites 5,6    Energy -26.828389818790    States   20 Truncation   0.007220338170
# Sweep 4 Sites 6,7    Energy -26.828421727943    States   20 Truncation   0.008009271410
# Sweep 4 Sites 7,8    Energy -26.828452651663    States   20 Truncation   0.008588591312
# Sweep 4 Sites 8,9    Energy -26.828574191448    States   20 Truncation   0.009304243400
# Sweep 4 Sites 9,10    Energy -26.828688561503    States   20 Truncation   0.009697823825
# Sweep 4 Sites 10,11    Energy -26.829033753371    States   20 Truncation   0.010651073167
# Sweep 4 Sites 11,12    Energy -26.829417882666    States   20 Truncation   0.010513234445
# Sweep 4 Sites 12,13    Energy -26.830138163582    States   20 Truncation   0.010808821723
# Sweep 4 Sites 13,14    Energy -26.830853063237    States   20 Truncation   0.010112643810
# Sweep 4 Sites 14,15    Energy -26.831407970871    States   20 Truncation   0.009119508944
# Sweep 4 Sites 15,16    Energy -26.831673243439    States   20 Truncation   0.006924871915
# Sweep 4 Sites 16,17    Energy -26.831696318090    States   20 Truncation   0.001949065792
# Sweep 4 Sites 17,18    Energy -26.831691059738    States    9 Truncation   0.000000000000
# Sweep 5 Sites 18,19    Energy -26.831691059738    States    3 Truncation   0.000000000000
# Sweep 5 Sites 17,18    Energy -26.831691059738    States    9 Truncation   0.000000000000
# Sweep 5 Sites 16,17    Energy -26.831696318090    States   20 Truncation   0.001949065792
# Sweep 5 Sites 15,16    Energy -26.831712125936    States   20 Truncation   0.007146688099
# Sweep 5 Sites 14,15    Energy -26.831726650082    States   20 Truncation   0.009994820447
# Sweep 5 Sites 13,14    Energy -26.831749419321    States   20 Truncation   0.011777623479
# Sweep 5 Sites 12,13    Energy -26.831802889307    States   20 Truncation   0.013436709001
# Sweep 5 Sites 11,12    Energy -26.831945210961    States   20 Truncation   0.013835654589
# Sweep 5 Sites 10,11    Energy -26.832256173032    States   20 Truncation   0.014588389052
# Sweep 5 Sites 9,10    Energy -26.832894964105    States   20 Truncation   0.014834265317
# Sweep 5 Sites 8,9    Energy -26.833740916012    States   20 Truncation   0.015541167910
# Sweep 5 Sites 7,8    Energy -26.834928327256    States   20 Truncation   0.015234692274
# Sweep 5 Sites 6,7    Energy -26.836127515285    States   20 Truncation   0.015313234184
# Sweep 5 Sites 5,6    Energy -26.837235908994    States   20 Truncation   0.013797856046
# Sweep 5 Sites 4,5    Energy -26.837991293801    States   20 Truncation   0.012834613260
# Sweep 5 Sites 3,4    Energy -26.838210233155    States   20 Truncation   0.009117309848
# Sweep 5 Sites 2,3    Energy -26.838279237054    States   20 Truncation   0.002159886274
# Sweep 5 Sites 1,2    Energy -26.838273579550    States    9 Truncation   0.000000000000
# Sweep 6 Sites 0,1    Energy -26.838273579550    States    3 Truncation   0.000000000000
# Sweep 6 Sites 1,2    Energy -26.838273579550    States    9 Truncation   0.000000000000
# Sweep 6 Sites 2,3    Energy -26.838279237054    States   20 Truncation   0.002159886274
# Sweep 6 Sites 3,4    Energy -26.838311265273    States   20 Truncation   0.009456766296
# Sweep 6 Sites 4,5    Energy -26.838336012742    States   20 Truncation   0.013463169143
# Sweep 6 Sites 5,6    Energy -26.838357424540    States   20 Truncation   0.015461344926
# Sweep 6 Sites 6,7    Energy -26.838393177972    States   20 Truncation   0.018330001846
# Sweep 6 Sites 7,8    Energy -26.838418148368    States   20 Truncation   0.018666076715
# Sweep 6 Sites 8,9    Energy -26.838470093130    States   20 Truncation   0.020319266727
# Sweep 6 Sites 9,10    Energy -26.838506148154    States   20 Truncation   0.019676588786
# Sweep 6 Sites 10,11    Energy -26.838562122715    States   20 Truncation   0.020402643097
# Sweep 6 Sites 11,12    Energy -26.838586909273    States   20 Truncation   0.018773841172
# Sweep 6 Sites 12,13    Energy -26.838614720684    States   20 Truncation   0.018500351013
# Sweep 6 Sites 13,14    Energy -26.838611153644    States   20 Truncation   0.015594411910
# Sweep 6 Sites 14,15    Energy -26.838606525414    States   20 Truncation   0.013567116324
# Sweep 6 Sites 15,16    Energy -26.838590164934    States   20 Truncation   0.009553720252
# Sweep 6 Sites 16,17    Energy -26.838558199020    States   20 Truncation   0.002165749346
# Sweep 6 Sites 17,18    Energy -26.838552527946    States    9 Truncation   0.000000000000
# Sweep 7 Sites 18,19    Energy -26.838552527946    States    3 Truncation   0.000000000000
# Sweep 7 Sites 17,18    Energy -26.838552527946    States    9 Truncation   0.000000000000
# Sweep 7 Sites 16,17    Energy -26.838558199020    States   20 Truncation   0.002165749346
# Sweep 7 Sites 15,16    Energy -26.838591682262    States   20 Truncation   0.009566918795
# Sweep 7 Sites 14,15    Energy -26.838616786613    States   20 Truncation   0.013667677987
# Sweep 7 Sites 13,14    Energy -26.838635576747    States   20 Truncation   0.015604543221
# Sweep 7 Sites 12,13    Energy -26.838663878742    States   20 Truncation   0.018787237509
# Sweep 7 Sites 11,12    Energy -26.838663981784    States   20 Truncation   0.018810328607
# Sweep 7 Sites 10,11    Energy -26.838685932731    States   20 Truncation   0.020858475279
# Sweep 7 Sites 9,10    Energy -26.838673864460    States   20 Truncation   0.019806158817
# Sweep 7 Sites 8,9    Energy -26.838686661285    States   20 Truncation   0.020863374779
# Sweep 7 Sites 7,8    Energy -26.838665415975    States   20 Truncation   0.018827648147
# Sweep 7 Sites 6,7    Energy -26.838666404575    States   20 Truncation   0.018801661535
# Sweep 7 Sites 5,6    Energy -26.838638743820    States   20 Truncation   0.015618456269
# Sweep 7 Sites 4,5    Energy -26.838620805406    States   20 Truncation   0.013677889303
# Sweep 7 Sites 3,4    Energy -26.838595977033    States   20 Truncation   0.009580429497
# Sweep 7 Sites 2,3    Energy -26.838562339085    States   20 Truncation   0.002166911937
# Sweep 7 Sites 1,2    Energy -26.838556664000    States    9 Truncation   0.000000000000
# Final energy expectation value -26.8385566639996
# variance =   0.007552639338

# %% [markdown]
# # Measurement

# %%
psi = [np.copy(Gs[i]) for i in range(0, len(Gs))]

# %%
def multi_site_measurement(MPS1,MPS2,op_list,pos_list):
    idx = np.argsort(pos_list)
    pos_list = np.array(pos_list)[idx]
    op_list = np.array(op_list)[idx]
    expectation = [[1]]
    # print(op_list,pos_list)
    assert len(op_list) == len(pos_list)
    for j in range(0, pos_list[0]):
        expectation = np.einsum("ik,sij->skj", expectation, MPS1[j])
        expectation = np.einsum("skj,skl->jl",  expectation,MPS2[j].conjugate())
    expectation = np.einsum('ik,sij,st,tkl->jl', expectation, MPS1[pos_list[0]], op_list[0], MPS2[pos_list[0]].conjugate())
    for i in range(len(op_list)-1):
        for j in range(pos_list[i]+1,pos_list[i+1]):
            expectation = np.einsum("ik,sij->skj", expectation, MPS1[j])
            expectation = np.einsum("skj,skl->jl", expectation,MPS2[j].conjugate())
        expectation = np.einsum('ik,sij,st,tkl->jl', expectation, MPS1[pos_list[i+1]], op_list[i+1], MPS2[pos_list[i+1]].conjugate())
    for j in range(pos_list[-1]+1,len(MPS1)):
        expectation = np.einsum("ik,sij->skj", expectation, MPS1[j])
        expectation = np.einsum("skj,skl->jl", expectation,MPS2[j].conjugate())
    return expectation[0][0]
def check_othogonal(MPS):
    infor_string = []
    for ten in MPS:
        matl = np.einsum("sij,sik->jk",ten,ten)
        matr = np.einsum("sij,slj->il",ten,ten)
        dim = matl.shape[0]
        Il = np.identity(dim)
        Ir = np.identity(matr.shape[0])
        if npla.norm(matl-Il)<1e-10:
            infor_string.append('A')
        if npla.norm(matr-Ir)<1e-10:
            infor_string.append('B')
        if not(npla.norm(matl-Il)<1e-10 or npla.norm(matr-Ir)<1e-10):
            infor_string.append('M')
    return ' '.join(infor_string)

def move_mix_site(start ,end , mix_MPS ,bond_dim):
    if end > start:
        move_dir = 'r'
        for i in range(start,end,1):
            M1 = mix_MPS[i]
            M_mat = np.reshape(M1,(M1.shape[0]*M1.shape[1],M1.shape[2]))
            A, S, B = np.linalg.svd(M_mat, full_matrices=0)
            trunc_dim = min(bond_dim,len(S))
            A = A[:,0:trunc_dim]
            S = S[0:trunc_dim]
            B = B[0:trunc_dim,:]
            # print(npla.norm(A@np.diag(S)@B-M_mat))
            trunc = np.sum(S[trunc_dim:])
            A = np.reshape(A,(M1.shape[0],M1.shape[1],-1))
            # print("Truncation error in moving from site {} to {} : {}".format(i,i+1,trunc))
            if trunc > 1e-10:
                raise Exception("large truncation error")
            B = np.diag(S)@B
            mix_MPS[i] =  A
            mix_MPS[i+1] = np.einsum("ij,sjk->sik",B,mix_MPS[i+1])
    if end < start:
        move_dir = 'l'
        for i in range(start,end,-1):
            M1 = mix_MPS[i]
            M_mat = np.reshape(M1.transpose(1,0,2), (M1.shape[1], M1.shape[0] * M1.shape[2]))
            A, S, B = np.linalg.svd(M_mat, full_matrices=0)
            trunc_dim = min(bond_dim, len(S))
            A = A[:, 0:trunc_dim]
            S = S[0:trunc_dim]
            B = B[0:trunc_dim, :]
            # print(npla.norm(A @ np.diag(S) @ B - M_mat))
            trunc = np.sum(S[trunc_dim:])
            B = np.reshape(B, (-1,M1.shape[0], M1.shape[2])).transpose(1,0,2)
            # print("Truncation error in moving from site {} to {} : {}".format(i, i + 1, trunc))
            if trunc > 1e-10:
                raise Exception("large truncation error")
            A = A@np.diag(S)
            mix_MPS[i] = B
            mix_MPS[i - 1] = np.einsum("sjk,kl->sjl", mix_MPS[i-1], A)
    if end == start:
        pass
    return mix_MPS

# %% [markdown]
# ## magnetization

# %%
def plot_Sz_r_MPS(MPS_in):
    Sz_correlation = []
    for i in range(N):
        Sz_correlation.append(multi_site_measurement(MPS_in, MPS_in, [Sz], [i]))
    plt.plot(Sz_correlation)
    plt.title(r"$<\hat{S}_z(x)>$")
    plt.xlabel("Site index")
    # plt.savefig("temp")
    # plt.ylim(-0.3, 0.3)
    plt.show()
    # plt.savefig("Sz_correlation_measurement")
    plt.close()
plot_Sz_r_MPS(psi)

# %% [markdown]
# ## Sz Sz correlation

# %%
def plot_Sz_correlaion_MPS(MPS_in):
    Sz_correlation = []
    for i in range(N):
        if i != N//2:
            Sz_correlation.append(multi_site_measurement(MPS_in,MPS_in,[Sz,Sz],[i,N//2]))
        else:
            Sz_correlation.append(multi_site_measurement(MPS_in, MPS_in, [Sz@Sz], [i]))
    plt.plot(Sz_correlation)
    plt.title(r"$<\hat{S}_z(x)\hat{S}_z(\frac{N}{2})>$")
    plt.xlabel("Site index")
    # plt.savefig("temp")
    plt.show()
    # plt.savefig("Sz_correlation_measurement")
    plt.close()
plot_Sz_correlaion_MPS(psi)

# %% [markdown]
# ## Entanglement entrophy

# %%
psi = [np.copy(Gs[i]) for i in range(0, len(Gs))]
ortho_info = check_othogonal(psi).split(" ")
for i in enumerate(ortho_info):
    if i[1] == "M":
        ortho_pos = i[0]
        break
for (i,char) in enumerate(ortho_info):
    if i<ortho_pos and char != "A":
        raise Exception("Left orthogonal error at site {}".format(i))
    if i>ortho_pos and char != "B":
        raise Exception("Right orthogonal error at site {}".format(i))
print("Orthogonality check passed, orthogonality center at site {}".format(ortho_pos))

psi = move_mix_site(ortho_pos,0,psi,D)
EE_list = []
for i in range(N-1):
    M1 = psi[i]
    M_mat = np.reshape(M1,(M1.shape[0]*M1.shape[1],M1.shape[2]))
    A, S, B = np.linalg.svd(M_mat, full_matrices=0)
    trunc_dim = min(D,len(S))
    A = A[:,0:trunc_dim]
    S = S[0:trunc_dim]
    # print(S)
    B = B[0:trunc_dim,:]
    order = 2
    EE = (1/(1-order))*np.log(np.sum((S**2)**order)) #-np.sum(S**2*np.log(S**2))
    EE_list.append(EE)
    A = np.reshape(A,(M1.shape[0],M1.shape[1],-1))
    # print("Truncation error in moving from site {} to {} : {}".format(i,i+1,trunc))
    B = np.diag(S)@B
    psi[i] =  A
    psi[i+1] = np.einsum("ij,sjk->sik",B,psi[i+1])
move_mix_site(N-1,0,psi,D)
plt.plot(np.arange(N-1)/N,EE_list,'o-')

plt.xlabel(r'$\frac{L_{system}}{L}$',fontsize = 14)
plt.show()
# plt.savefig("Sz_correlation_measurement")
plt.close()
# Out:
# Orthogonality check passed, orthogonality center at site 1

# %% [markdown]
# # Scaling

# %%
d = 3  # local bond dimension
totEE = []
for N in [16,32,48]:  # number of sites
    D = 32 # virtue bond dimension

    InitialA1 = np.zeros((d, 1, 1))
    InitialA1[0, 0, 0] = 1
    InitialA2 = np.zeros((d, 1, 1))
    InitialA2[2, 0, 0] = 1

    ## initial state |01010101>
    MPS = [InitialA1, InitialA2] * int(N / 2)

    I = np.identity(d)
    Z = np.zeros((d, d))
    Sz = np.zeros((d, d))
    Sp = np.zeros((d, d))
    Sm = np.zeros((d, d))

    sz_lsit = []
    if d%2 == 0:
        print('Half integer Spin')
        step = 0.5
        for i in range(d//2):
            sz_lsit.append((i+1)*step)
            sz_lsit.append(-(i+1)*step)
        sz_lsit = sorted(sz_lsit)
    else:
        print('Integer Spin')
        step = 1
        sz_lsit.append(0)
        for i in range(d//2):
            sz_lsit.append((i+1)*step)
            sz_lsit.append(-(i+1)*step)
        sz_lsit = sorted(sz_lsit)
    # print('Spin values: {}'.format(sz_lsit))

    Sz = np.diag(sz_lsit)
    Sz = Sz.astype('float64') 
    for i in range(d-1):
        Sp[i+1,i] = np.sqrt(2-sz_lsit[i]*(sz_lsit[i]+1)) 
    for i in range(d-1):
        Sm[i,i+1] = np.sqrt(2-sz_lsit[i]*(sz_lsit[i]+1)) 
    # print('Spin chain with total Spin: {}'.format((d-1)/2))
    print('Sz matrix form: \n =============')
    print(Sz)
    print('S+ matrix form: \n =============')
    print(Sp)
    print('S- matrix form: \n =============')
    print(Sm)

    ## Hamiltonian MPO
    W = np.array([[I, Sz, 0.5 * Sp, 0.5 * Sm, Z],
                [Z, Z, Z, Z, Sz],
                [Z, Z, Z, Z, Sm],
                [Z, Z, Z, Z, Sp],
                [Z, Z, Z, Z, I]])

    Wfirst = np.array([[I, Sz, 0.5 * Sp, 0.5 * Sm, Z]])

    Wlast = np.array([[Z], [Sz], [Sm], [Sp], [I]])

    # the complete MPO
    MPO = [Wfirst] + ([W] * (N - 2)) + [Wlast]

    # 8 sweeps with m=10 states
    HamSquared = product_MPO(MPO, MPO)

    Gs = two_site_dmrg(MPS, MPO, D, 8)

    Energy = Expectation(Gs, MPO, Gs)
    print("Final energy expectation value {}".format(Energy))

    H2 = Expectation(Gs, HamSquared, Gs)
    print("variance = {:16.12f}".format(H2 - Energy * Energy))

    psi = [np.copy(Gs[i]) for i in range(0, len(Gs))]
    ortho_info = check_othogonal(psi).split(" ")
    for i in enumerate(ortho_info):
        if i[1] == "M":
            ortho_pos = i[0]
            break
    psi = move_mix_site(ortho_pos,0,psi,D)
    EE_list = []
    for i in range(N-1):
        M1 = psi[i]
        M_mat = np.reshape(M1,(M1.shape[0]*M1.shape[1],M1.shape[2]))
        A, S, B = np.linalg.svd(M_mat, full_matrices=0)
        trunc_dim = min(D,len(S))
        A = A[:,0:trunc_dim]
        S = S[0:trunc_dim]
        # print(S)
        B = B[0:trunc_dim,:]
        order = 2
        EE = (1/(1-order))*np.log(np.sum((S**2)**order)) #-np.sum(S**2*np.log(S**2))
        EE_list.append(EE)
        A = np.reshape(A,(M1.shape[0],M1.shape[1],-1))
        # print("Truncation error in moving from site {} to {} : {}".format(i,i+1,trunc))
        B = np.diag(S)@B
        psi[i] =  A
        psi[i+1] = np.einsum("ij,sjk->sik",B,psi[i+1])
    move_mix_site(N-1,0,psi,D)
    # plt.plot(np.arange(N-1)/N,EE_list,'o-',label = f"L = {N}, mm = 32")
    totEE.append(EE_list)
# Out:
# Integer Spin
# Sz matrix form:
#  =============
# [[-1.  0.  0.]
#  [ 0.  0.  0.]
#  [ 0.  0.  1.]]
# S+ matrix form:
#  =============
# [[0.         0.         0.        ]
#  [1.41421356 0.         0.        ]
#  [0.         1.41421356 0.        ]]
# S- matrix form:
#  =============
# [[0.         1.41421356 0.        ]
#  [0.         0.         1.41421356]
#  [0.         0.         0.        ]]
# Sweep 0 Sites 0,1    Energy -15.481194304092    States    3 Truncation   0.000000000000
# Sweep 0 Sites 1,2    Energy -15.827550196615    States    3 Truncation   0.000000000000
# Sweep 0 Sites 2,3    Energy -16.203481362554    States    3 Truncation   0.000000000000
# Sweep 0 Sites 3,4    Energy -16.567121450138    States    3 Truncation   0.000000000000
# Sweep 0 Sites 4,5    Energy -16.932138072781    States    3 Truncation   0.000000000000
# Sweep 0 Sites 5,6    Energy -17.295992885665    States    3 Truncation   0.000000000000
# Sweep 0 Sites 6,7    Energy -17.659816720597    States    3 Truncation   0.000000000000
# Sweep 0 Sites 7,8    Energy -18.023503340587    States    3 Truncation   0.000000000000
# Sweep 0 Sites 8,9    Energy -18.387163904762    States    3 Truncation   0.000000000000
# Sweep 0 Sites 9,10    Energy -18.750804560921    States    3 Truncation   0.000000000000
# Sweep 0 Sites 10,11    Energy -19.114438977516    States    3 Truncation   0.000000000000
# Sweep 0 Sites 11,12    Energy -19.478070101678    States    3 Truncation   0.000000000000
# Sweep 0 Sites 12,13    Energy -19.841699974205    States    3 Truncation   0.000000000000
# Sweep 0 Sites 13,14    Energy -20.205329266131    States    3 Truncation   0.000000000000
# Sweep 1 Sites 14,15    Energy -20.760526422838    States    3 Truncation   0.000000000000
# Sweep 1 Sites 13,14    Energy -20.801859337058    States    9 Truncation   0.000000000000
# Sweep 1 Sites 12,13    Energy -20.819799586475    States    9 Truncation   0.000000000000
# Sweep 1 Sites 11,12    Energy -20.851367869574    States    9 Truncation   0.000000000000
# Sweep 1 Sites 10,11    Energy -20.876656968289    States    9 Truncation   0.000000000000
# Sweep 1 Sites 9,10    Energy -20.906493783932    States    9 Truncation   0.000000000000
# Sweep 1 Sites 8,9    Energy -20.935139544344    States    9 Truncation   0.000000000000
# Sweep 1 Sites 7,8    Energy -20.965499123744    States    9 Truncation   0.000000000000
# Sweep 1 Sites 6,7    Energy -20.995924315599    States    9 Truncation   0.000000000000
# Sweep 1 Sites 5,6    Energy -21.027372747549    States    9 Truncation   0.000000000000
# Sweep 1 Sites 4,5    Energy -21.058967060384    States    9 Truncation   0.000000000000
# Sweep 1 Sites 3,4    Energy -21.093677544010    States    9 Truncation   0.000000000000
# Sweep 1 Sites 2,3    Energy -21.123961185538    States    9 Truncation   0.000000000000
# Sweep 1 Sites 1,2    Energy -21.193797792270    States    9 Truncation   0.000000000000
# Sweep 2 Sites 0,1    Energy -21.193797792270    States    3 Truncation   0.000000000000
# Sweep 2 Sites 1,2    Energy -21.193797792270    States    9 Truncation   0.000000000000
# Sweep 2 Sites 2,3    Energy -21.198009836898    States   27 Truncation   0.000000000000
# Sweep 2 Sites 3,4    Energy -21.198825308095    States   27 Truncation   0.000000000000
# Sweep 2 Sites 4,5    Energy -21.202375757977    States   27 Truncation   0.000000000000
# Sweep 2 Sites 5,6    Energy -21.204135320642    States   27 Truncation   0.000000000000
# Sweep 2 Sites 6,7    Energy -21.207336038154    States   27 Truncation   0.000000000000
# Sweep 2 Sites 7,8    Energy -21.209614793335    States   27 Truncation   0.000000000000
# Sweep 2 Sites 8,9    Energy -21.212755582280    States   27 Truncation   0.000000000000
# Sweep 2 Sites 9,10    Energy -21.214986089653    States   27 Truncation   0.000000000000
# Sweep 2 Sites 10,11    Energy -21.218668840111    States   27 Truncation   0.000000000000
# Sweep 2 Sites 11,12    Energy -21.220038792210    States   27 Truncation   0.000000000000
# Sweep 2 Sites 12,13    Energy -21.227802520740    States   27 Truncation   0.000000000000
# Sweep 2 Sites 13,14    Energy -21.227802520740    States    9 Truncation   0.000000000000
# Sweep 3 Sites 14,15    Energy -21.227802520740    States    3 Truncation   0.000000000000
# Sweep 3 Sites 13,14    Energy -21.227802520740    States    9 Truncation   0.000000000000
# Sweep 3 Sites 12,13    Energy -21.227802520740    States   27 Truncation   0.000000000000
# Sweep 3 Sites 11,12    Energy -21.228057301940    States   32 Truncation   0.000411014347
# Sweep 3 Sites 10,11    Energy -21.228066206293    States   32 Truncation   0.000498667829
# Sweep 3 Sites 9,10    Energy -21.228681451504    States   32 Truncation   0.000899067381
# Sweep 3 Sites 8,9    Energy -21.228705549032    States   32 Truncation   0.000813206795
# Sweep 3 Sites 7,8    Energy -21.230244407743    States   32 Truncation   0.001584013815
# Sweep 3 Sites 6,7    Energy -21.230306690387    States   32 Truncation   0.001275376055
# Sweep 3 Sites 5,6    Energy -21.236119424079    States   32 Truncation   0.002739602118
# Sweep 3 Sites 4,5    Energy -21.236345635553    States   32 Truncation   0.001794631978
# Sweep 3 Sites 3,4    Energy -21.246812355282    States   32 Truncation   0.002429530803
# Sweep 3 Sites 2,3    Energy -21.246808334514    States   27 Truncation   0.000000000000
# Sweep 3 Sites 1,2    Energy -21.246808334514    States    9 Truncation   0.000000000000
# Sweep 4 Sites 0,1    Energy -21.246808334514    States    3 Truncation   0.000000000000
# Sweep 4 Sites 1,2    Energy -21.246808334514    States    9 Truncation   0.000000000000
# Sweep 4 Sites 2,3    Energy -21.246808334514    States   27 Truncation   0.000000000000
# Sweep 4 Sites 3,4    Energy -21.246812355282    States   32 Truncation   0.002429530803
# Sweep 4 Sites 4,5    Energy -21.246990223064    States   32 Truncation   0.004206975030
# Sweep 4 Sites 5,6    Energy -21.247099082355    States   32 Truncation   0.005151702876
# Sweep 4 Sites 6,7    Energy -21.248015271084    States   32 Truncation   0.006027736189
# Sweep 4 Sites 7,8    Energy -21.248394531709    States   32 Truncation   0.006103243186
# Sweep 4 Sites 8,9    Energy -21.249413229750    States   32 Truncation   0.006116252173
# Sweep 4 Sites 9,10    Energy -21.249718816809    States   32 Truncation   0.005347039421
# Sweep 4 Sites 10,11    Energy -21.250075462518    States   32 Truncation   0.004303790473
# Sweep 4 Sites 11,12    Energy -21.250120771851    States   32 Truncation   0.002638772932
# Sweep 4 Sites 12,13    Energy -21.250115780978    States   27 Truncation   0.000000000000
# Sweep 4 Sites 13,14    Energy -21.250115780978    States    9 Truncation   0.000000000000
# Sweep 5 Sites 14,15    Energy -21.250115780978    States    3 Truncation   0.000000000000
# Sweep 5 Sites 13,14    Energy -21.250115780978    States    9 Truncation   0.000000000000
# Sweep 5 Sites 12,13    Energy -21.250115780978    States   27 Truncation   0.000000000000
# Sweep 5 Sites 11,12    Energy -21.250120771851    States   32 Truncation   0.002638772932
# Sweep 5 Sites 10,11    Energy -21.250122418489    States   32 Truncation   0.004384753673
# Sweep 5 Sites 9,10    Energy -21.250129238747    States   32 Truncation   0.005733356886
# Sweep 5 Sites 8,9    Energy -21.250129483284    States   32 Truncation   0.006551859477
# Sweep 5 Sites 7,8    Energy -21.250133458002    States   32 Truncation   0.006775924836
# Sweep 5 Sites 6,7    Energy -21.250131620356    States   32 Truncation   0.006550689669
# Sweep 5 Sites 5,6    Energy -21.250131803517    States   32 Truncation   0.005745516777
# Sweep 5 Sites 4,5    Energy -21.250125128915    States   32 Truncation   0.004389893467
# Sweep 5 Sites 3,4    Energy -21.250123533905    States   32 Truncation   0.002641688844
# Sweep 5 Sites 2,3    Energy -21.250118530179    States   27 Truncation   0.000000000000
# Sweep 5 Sites 1,2    Energy -21.250118530179    States    9 Truncation   0.000000000000
# Sweep 6 Sites 0,1    Energy -21.250118530179    States    3 Truncation   0.000000000000
# Sweep 6 Sites 1,2    Energy -21.250118530179    States    9 Truncation   0.000000000000
# Sweep 6 Sites 2,3    Energy -21.250118530179    States   27 Truncation   0.000000000000
# Sweep 6 Sites 3,4    Energy -21.250123533905    States   32 Truncation   0.002641688844
# Sweep 6 Sites 4,5    Energy -21.250125201901    States   32 Truncation   0.004395305054
# Sweep 6 Sites 5,6    Energy -21.250132078238    States   32 Truncation   0.005747446523
# Sweep 6 Sites 6,7    Energy -21.250132256012    States   32 Truncation   0.006567796948
# Sweep 6 Sites 7,8    Energy -21.250136019509    States   32 Truncation   0.006799844467
# Sweep 6 Sites 8,9    Energy -21.250132251332    States   32 Truncation   0.006567760114
# Sweep 6 Sites 9,10    Energy -21.250132077147    States   32 Truncation   0.005747630426
# Sweep 6 Sites 10,11    Energy -21.250125192926    States   32 Truncation   0.004395300232
# Sweep 6 Sites 11,12    Energy -21.250123525285    States   32 Truncation   0.002641759516
# Sweep 6 Sites 12,13    Energy -21.250118520795    States   27 Truncation   0.000000000000
# Sweep 6 Sites 13,14    Energy -21.250118520795    States    9 Truncation   0.000000000000
# Sweep 7 Sites 14,15    Energy -21.250118520795    States    3 Truncation   0.000000000000
# Sweep 7 Sites 13,14    Energy -21.250118520795    States    9 Truncation   0.000000000000
# Sweep 7 Sites 12,13    Energy -21.250118520795    States   27 Truncation   0.000000000000
# Sweep 7 Sites 11,12    Energy -21.250123525285    States   32 Truncation   0.002641759516
# Sweep 7 Sites 10,11    Energy -21.250125189809    States   32 Truncation   0.004395297407
# Sweep 7 Sites 9,10    Energy -21.250132074144    States   32 Truncation   0.005747698077
# Sweep 7 Sites 8,9    Energy -21.250132233591    States   32 Truncation   0.006568073905
# Sweep 7 Sites 7,8    Energy -21.250136018935    States   32 Truncation   0.006800084535
# Sweep 7 Sites 6,7    Energy -21.250132231733    States   32 Truncation   0.006568075979
# Sweep 7 Sites 5,6    Energy -21.250132070687    States   32 Truncation   0.005747723367
# Sweep 7 Sites 4,5    Energy -21.250125185537    States   32 Truncation   0.004395301166
# Sweep 7 Sites 3,4    Energy -21.250123520724    States   32 Truncation   0.002641772157
# Sweep 7 Sites 2,3    Energy -21.250118516135    States   27 Truncation   0.000000000000
# Sweep 7 Sites 1,2    Energy -21.250118516135    States    9 Truncation   0.000000000000
# Final energy expectation value -21.250118516135203
# variance =   0.000606264046
# Integer Spin
# Sz matrix form:
#  =============
# [[-1.  0.  0.]
#  [ 0.  0.  0.]
#  [ 0.  0.  1.]]
# S+ matrix form:
#  =============
# [[0.         0.         0.        ]
#  [1.41421356 0.         0.        ]
#  [0.         1.41421356 0.        ]]
# S- matrix form:
#  =============
# [[0.         1.41421356 0.        ]
#  [0.         0.         1.41421356]
#  [0.         0.         0.        ]]
# Sweep 0 Sites 0,1    Energy -31.481194304092    States    3 Truncation   0.000000000000
# Sweep 0 Sites 1,2    Energy -31.827550196615    States    3 Truncation   0.000000000000
# Sweep 0 Sites 2,3    Energy -32.203481362554    States    3 Truncation   0.000000000000
# Sweep 0 Sites 3,4    Energy -32.567121450138    States    3 Truncation   0.000000000000
# Sweep 0 Sites 4,5    Energy -32.932138072781    States    3 Truncation   0.000000000000
# Sweep 0 Sites 5,6    Energy -33.295992885665    States    3 Truncation   0.000000000000
# Sweep 0 Sites 6,7    Energy -33.659816720597    States    3 Truncation   0.000000000000
# Sweep 0 Sites 7,8    Energy -34.023503340587    States    3 Truncation   0.000000000000
# Sweep 0 Sites 8,9    Energy -34.387163904762    States    3 Truncation   0.000000000000
# Sweep 0 Sites 9,10    Energy -34.750804560921    States    3 Truncation   0.000000000000
# Sweep 0 Sites 10,11    Energy -35.114438977516    States    3 Truncation   0.000000000000
# Sweep 0 Sites 11,12    Energy -35.478070101678    States    3 Truncation   0.000000000000
# Sweep 0 Sites 12,13    Energy -35.841699974205    States    3 Truncation   0.000000000000
# Sweep 0 Sites 13,14    Energy -36.205329266131    States    3 Truncation   0.000000000000
# Sweep 0 Sites 14,15    Energy -36.568958320115    States    3 Truncation   0.000000000000
# Sweep 0 Sites 15,16    Energy -36.932587268884    States    3 Truncation   0.000000000000
# Sweep 0 Sites 16,17    Energy -37.296216173268    States    3 Truncation   0.000000000000
# Sweep 0 Sites 17,18    Energy -37.659845058376    States    3 Truncation   0.000000000000
# Sweep 0 Sites 18,19    Energy -38.023473935263    States    3 Truncation   0.000000000000
# Sweep 0 Sites 19,20    Energy -38.387102808604    States    3 Truncation   0.000000000000
# Sweep 0 Sites 20,21    Energy -38.750731680426    States    3 Truncation   0.000000000000
# Sweep 0 Sites 21,22    Energy -39.114360551594    States    3 Truncation   0.000000000000
# Sweep 0 Sites 22,23    Energy -39.477989422482    States    3 Truncation   0.000000000000
# Sweep 0 Sites 23,24    Energy -39.841618293250    States    3 Truncation   0.000000000000
# Sweep 0 Sites 24,25    Energy -40.205247163966    States    3 Truncation   0.000000000000
# Sweep 0 Sites 25,26    Energy -40.568876034659    States    3 Truncation   0.000000000000
# Sweep 0 Sites 26,27    Energy -40.932504905343    States    3 Truncation   0.000000000000
# Sweep 0 Sites 27,28    Energy -41.296133776023    States    3 Truncation   0.000000000000
# Sweep 0 Sites 28,29    Energy -41.659762646702    States    3 Truncation   0.000000000000
# Sweep 0 Sites 29,30    Energy -42.023391517379    States    3 Truncation   0.000000000000
# Sweep 1 Sites 30,31    Energy -42.578588297260    States    3 Truncation   0.000000000000
# Sweep 1 Sites 29,30    Energy -42.619920856413    States    9 Truncation   0.000000000000
# Sweep 1 Sites 28,29    Energy -42.637860703234    States    9 Truncation   0.000000000000
# Sweep 1 Sites 27,28    Energy -42.669427295743    States    9 Truncation   0.000000000000
# Sweep 1 Sites 26,27    Energy -42.694713230648    States    9 Truncation   0.000000000000
# Sweep 1 Sites 25,26    Energy -42.724540570946    States    9 Truncation   0.000000000000
# Sweep 1 Sites 24,25    Energy -42.753167486829    States    9 Truncation   0.000000000000
# Sweep 1 Sites 23,24    Energy -42.783469299620    States    9 Truncation   0.000000000000
# Sweep 1 Sites 22,23    Energy -42.813800581140    States    9 Truncation   0.000000000000
# Sweep 1 Sites 21,22    Energy -42.844863067755    States    9 Truncation   0.000000000000
# Sweep 1 Sites 20,21    Energy -42.876159983329    States    9 Truncation   0.000000000000
# Sweep 1 Sites 19,20    Energy -42.907834306041    States    9 Truncation   0.000000000000
# Sweep 1 Sites 18,19    Energy -42.939717775796    States    9 Truncation   0.000000000000
# Sweep 1 Sites 17,18    Energy -42.971820098616    States    9 Truncation   0.000000000000
# Sweep 1 Sites 16,17    Energy -43.004073473228    States    9 Truncation   0.000000000000
# Sweep 1 Sites 15,16    Energy -43.036462105753    States    9 Truncation   0.000000000000
# Sweep 1 Sites 14,15    Energy -43.068953105409    States    9 Truncation   0.000000000000
# Sweep 1 Sites 13,14    Energy -43.101530413173    States    9 Truncation   0.000000000000
# Sweep 1 Sites 12,13    Energy -43.134175842555    States    9 Truncation   0.000000000000
# Sweep 1 Sites 11,12    Energy -43.166877977640    States    9 Truncation   0.000000000000
# Sweep 1 Sites 10,11    Energy -43.199626859911    States    9 Truncation   0.000000000000
# Sweep 1 Sites 9,10    Energy -43.232418417446    States    9 Truncation   0.000000000000
# Sweep 1 Sites 8,9    Energy -43.265250413125    States    9 Truncation   0.000000000000
# Sweep 1 Sites 7,8    Energy -43.298147509032    States    9 Truncation   0.000000000000
# Sweep 1 Sites 6,7    Energy -43.331104155598    States    9 Truncation   0.000000000000
# Sweep 1 Sites 5,6    Energy -43.364383427630    States    9 Truncation   0.000000000000
# Sweep 1 Sites 4,5    Energy -43.397587520044    States    9 Truncation   0.000000000000
# Sweep 1 Sites 3,4    Energy -43.433630416186    States    9 Truncation   0.000000000000
# Sweep 1 Sites 2,3    Energy -43.464918173824    States    9 Truncation   0.000000000000
# Sweep 1 Sites 1,2    Energy -43.536196759918    States    9 Truncation   0.000000000000
# Sweep 2 Sites 0,1    Energy -43.536196759918    States    3 Truncation   0.000000000000
# Sweep 2 Sites 1,2    Energy -43.536196759918    States    9 Truncation   0.000000000000
# Sweep 2 Sites 2,3    Energy -43.540513808571    States   27 Truncation   0.000000000000
# Sweep 2 Sites 3,4    Energy -43.541382932422    States   27 Truncation   0.000000000000
# Sweep 2 Sites 4,5    Energy -43.545113772264    States   27 Truncation   0.000000000000
# Sweep 2 Sites 5,6    Energy -43.547084513717    States   27 Truncation   0.000000000000
# Sweep 2 Sites 6,7    Energy -43.550588298923    States   27 Truncation   0.000000000000
# Sweep 2 Sites 7,8    Energy -43.553389130403    States   27 Truncation   0.000000000000
# Sweep 2 Sites 8,9    Energy -43.556978676011    States   27 Truncation   0.000000000000
# Sweep 2 Sites 9,10    Energy -43.560358095751    States   27 Truncation   0.000000000000
# Sweep 2 Sites 10,11    Energy -43.564152198330    States   27 Truncation   0.000000000000
# Sweep 2 Sites 11,12    Energy -43.567929135575    States   27 Truncation   0.000000000000
# Sweep 2 Sites 12,13    Energy -43.571933166593    States   27 Truncation   0.000000000000
# Sweep 2 Sites 13,14    Energy -43.575975999260    States   27 Truncation   0.000000000000
# Sweep 2 Sites 14,15    Energy -43.580144760286    States   27 Truncation   0.000000000000
# Sweep 2 Sites 15,16    Energy -43.584351851972    States   27 Truncation   0.000000000000
# Sweep 2 Sites 16,17    Energy -43.588622128291    States   27 Truncation   0.000000000000
# Sweep 2 Sites 17,18    Energy -43.592906115565    States   27 Truncation   0.000000000000
# Sweep 2 Sites 18,19    Energy -43.597206570915    States   27 Truncation   0.000000000000
# Sweep 2 Sites 19,20    Energy -43.601478315774    States   27 Truncation   0.000000000000
# Sweep 2 Sites 20,21    Energy -43.605727394533    States   27 Truncation   0.000000000000
# Sweep 2 Sites 21,22    Energy -43.609871437083    States   27 Truncation   0.000000000000
# Sweep 2 Sites 22,23    Energy -43.613973565944    States   27 Truncation   0.000000000000
# Sweep 2 Sites 23,24    Energy -43.617796456745    States   27 Truncation   0.000000000000
# Sweep 2 Sites 24,25    Energy -43.621685385220    States   27 Truncation   0.000000000000
# Sweep 2 Sites 25,26    Energy -43.624808713962    States   27 Truncation   0.000000000000
# Sweep 2 Sites 26,27    Energy -43.628924615506    States   27 Truncation   0.000000000000
# Sweep 2 Sites 27,28    Energy -43.630640804127    States   27 Truncation   0.000000000000
# Sweep 2 Sites 28,29    Energy -43.638431281475    States   27 Truncation   0.000000000000
# Sweep 2 Sites 29,30    Energy -43.638431281475    States    9 Truncation   0.000000000000
# Sweep 3 Sites 30,31    Energy -43.638431281475    States    3 Truncation   0.000000000000
# Sweep 3 Sites 29,30    Energy -43.638431281475    States    9 Truncation   0.000000000000
# Sweep 3 Sites 28,29    Energy -43.638431281475    States   27 Truncation   0.000000000000
# Sweep 3 Sites 27,28    Energy -43.638583406541    States   32 Truncation   0.000354352820
# Sweep 3 Sites 26,27    Energy -43.638590700446    States   32 Truncation   0.000438139196
# Sweep 3 Sites 25,26    Energy -43.638771657601    States   32 Truncation   0.000606994864
# Sweep 3 Sites 24,25    Energy -43.638788002961    States   32 Truncation   0.000615715407
# Sweep 3 Sites 23,24    Energy -43.638910376611    States   32 Truncation   0.000711272619
# Sweep 3 Sites 22,23    Energy -43.638934553530    States   32 Truncation   0.000671434589
# Sweep 3 Sites 21,22    Energy -43.639015281385    States   32 Truncation   0.000752480983
# Sweep 3 Sites 20,21    Energy -43.639045873146    States   32 Truncation   0.000666731233
# Sweep 3 Sites 19,20    Energy -43.639105517544    States   32 Truncation   0.000721935069
# Sweep 3 Sites 18,19    Energy -43.639140980624    States   32 Truncation   0.000655871714
# Sweep 3 Sites 17,18    Energy -43.639191252693    States   32 Truncation   0.000681352686
# Sweep 3 Sites 16,17    Energy -43.639229959106    States   32 Truncation   0.000639706735
# Sweep 3 Sites 15,16    Energy -43.639276687731    States   32 Truncation   0.000649063944
# Sweep 3 Sites 14,15    Energy -43.639317072185    States   32 Truncation   0.000626792952
# Sweep 3 Sites 13,14    Energy -43.639363267813    States   32 Truncation   0.000631434302
# Sweep 3 Sites 12,13    Energy -43.639403693917    States   32 Truncation   0.000618374662
# Sweep 3 Sites 11,12    Energy -43.639452607182    States   32 Truncation   0.000634344177
# Sweep 3 Sites 10,11    Energy -43.639491176753    States   32 Truncation   0.000620126304
# Sweep 3 Sites 9,10    Energy -43.639552350332    States   32 Truncation   0.000675258701
# Sweep 3 Sites 8,9    Energy -43.639586371870    States   32 Truncation   0.000649932431
# Sweep 3 Sites 7,8    Energy -43.639687614398    States   32 Truncation   0.000739589818
# Sweep 3 Sites 6,7    Energy -43.639712850352    States   32 Truncation   0.000675984064
# Sweep 3 Sites 5,6    Energy -43.639885175809    States   32 Truncation   0.000720546814
# Sweep 3 Sites 4,5    Energy -43.639897705179    States   32 Truncation   0.000552065379
# Sweep 3 Sites 3,4    Energy -43.640051641851    States   32 Truncation   0.000500211135
# Sweep 3 Sites 2,3    Energy -43.640051513897    States   27 Truncation   0.000000000000
# Sweep 3 Sites 1,2    Energy -43.640051513896    States    9 Truncation   0.000000000000
# Sweep 4 Sites 0,1    Energy -43.640051513896    States    3 Truncation   0.000000000000
# Sweep 4 Sites 1,2    Energy -43.640051513896    States    9 Truncation   0.000000000000
# Sweep 4 Sites 2,3    Energy -43.640051513896    States   27 Truncation   0.000000000000
# Sweep 4 Sites 3,4    Energy -43.640051641851    States   32 Truncation   0.000500211135
# Sweep 4 Sites 4,5    Energy -43.640051897375    States   32 Truncation   0.000795542751
# Sweep 4 Sites 5,6    Energy -43.640052071903    States   32 Truncation   0.001026874087
# Sweep 4 Sites 6,7    Energy -43.640053275313    States   32 Truncation   0.001150901751
# Sweep 4 Sites 7,8    Energy -43.640053667017    States   32 Truncation   0.001268042404
# Sweep 4 Sites 8,9    Energy -43.640055799803    States   32 Truncation   0.001328303939
# Sweep 4 Sites 9,10    Energy -43.640056488833    States   32 Truncation   0.001370093288
# Sweep 4 Sites 10,11    Energy -43.640058741178    States   32 Truncation   0.001391045156
# Sweep 4 Sites 11,12    Energy -43.640059313534    States   32 Truncation   0.001360675442
# Sweep 4 Sites 12,13    Energy -43.640061210855    States   32 Truncation   0.001388165690
# Sweep 4 Sites 13,14    Energy -43.640061727015    States   32 Truncation   0.001360023572
# Sweep 4 Sites 14,15    Energy -43.640063406316    States   32 Truncation   0.001405523629
# Sweep 4 Sites 15,16    Energy -43.640063944211    States   32 Truncation   0.001394789192
# Sweep 4 Sites 16,17    Energy -43.640065743152    States   32 Truncation   0.001462981696
# Sweep 4 Sites 17,18    Energy -43.640066382364    States   32 Truncation   0.001464962301
# Sweep 4 Sites 18,19    Energy -43.640068492177    States   32 Truncation   0.001511788357
# Sweep 4 Sites 19,20    Energy -43.640069324687    States   32 Truncation   0.001526884689
# Sweep 4 Sites 20,21    Energy -43.640071817241    States   32 Truncation   0.001505081671
# Sweep 4 Sites 21,22    Energy -43.640072798433    States   32 Truncation   0.001518542233
# Sweep 4 Sites 22,23    Energy -43.640075308444    States   32 Truncation   0.001441899938
# Sweep 4 Sites 23,24    Energy -43.640075762894    States   32 Truncation   0.001379771902
# Sweep 4 Sites 24,25    Energy -43.640077265797    States   32 Truncation   0.001233631213
# Sweep 4 Sites 25,26    Energy -43.640077399805    States   32 Truncation   0.001102314220
# Sweep 4 Sites 26,27    Energy -43.640077674781    States   32 Truncation   0.000836159047
# Sweep 4 Sites 27,28    Energy -43.640077612921    States   32 Truncation   0.000522285055
# Sweep 4 Sites 28,29    Energy -43.640077478508    States   27 Truncation   0.000000000000
# Sweep 4 Sites 29,30    Energy -43.640077478508    States    9 Truncation   0.000000000000
# Sweep 5 Sites 30,31    Energy -43.640077478508    States    3 Truncation   0.000000000000
# Sweep 5 Sites 29,30    Energy -43.640077478508    States    9 Truncation   0.000000000000
# Sweep 5 Sites 28,29    Energy -43.640077478508    States   27 Truncation   0.000000000000
# Sweep 5 Sites 27,28    Energy -43.640077612921    States   32 Truncation   0.000522285055
# Sweep 5 Sites 26,27    Energy -43.640077708745    States   32 Truncation   0.000838028810
# Sweep 5 Sites 25,26    Energy -43.640077858972    States   32 Truncation   0.001120351636
# Sweep 5 Sites 24,25    Energy -43.640077952720    States   32 Truncation   0.001252515593
# Sweep 5 Sites 23,24    Energy -43.640078103591    States   32 Truncation   0.001430566987
# Sweep 5 Sites 22,23    Energy -43.640078177397    States   32 Truncation   0.001493829476
# Sweep 5 Sites 21,22    Energy -43.640078304878    States   32 Truncation   0.001599730111
# Sweep 5 Sites 20,21    Energy -43.640078351145    States   32 Truncation   0.001629241179
# Sweep 5 Sites 19,20    Energy -43.640078518088    States   32 Truncation   0.001703557962
# Sweep 5 Sites 18,19    Energy -43.640078635534    States   32 Truncation   0.001677610473
# Sweep 5 Sites 17,18    Energy -43.640079368815    States   32 Truncation   0.001729929348
# Sweep 5 Sites 16,17    Energy -43.640080303042    States   32 Truncation   0.001738063478
# Sweep 5 Sites 15,16    Energy -43.640081886551    States   32 Truncation   0.001800648310
# Sweep 5 Sites 14,15    Energy -43.640083871331    States   32 Truncation   0.001818974208
# Sweep 5 Sites 13,14    Energy -43.640086891472    States   32 Truncation   0.001900477379
# Sweep 5 Sites 12,13    Energy -43.640090453861    States   32 Truncation   0.001918035516
# Sweep 5 Sites 11,12    Energy -43.640095324300    States   32 Truncation   0.002017009670
# Sweep 5 Sites 10,11    Energy -43.640097233703    States   32 Truncation   0.001912189569
# Sweep 5 Sites 9,10    Energy -43.640100480814    States   32 Truncation   0.001925275920
# Sweep 5 Sites 8,9    Energy -43.640102683321    States   32 Truncation   0.001784645470
# Sweep 5 Sites 7,8    Energy -43.640103858413    States   32 Truncation   0.001726455613
# Sweep 5 Sites 6,7    Energy -43.640104036566    States   32 Truncation   0.001473187217
# Sweep 5 Sites 5,6    Energy -43.640104152829    States   32 Truncation   0.001304179088
# Sweep 5 Sites 4,5    Energy -43.640103967597    States   32 Truncation   0.000941686498
# Sweep 5 Sites 3,4    Energy -43.640103864969    States   32 Truncation   0.000572124545
# Sweep 5 Sites 2,3    Energy -43.640103704710    States   27 Truncation   0.000000000000
# Sweep 5 Sites 1,2    Energy -43.640103704710    States    9 Truncation   0.000000000000
# Sweep 6 Sites 0,1    Energy -43.640103704710    States    3 Truncation   0.000000000000
# Sweep 6 Sites 1,2    Energy -43.640103704710    States    9 Truncation   0.000000000000
# Sweep 6 Sites 2,3    Energy -43.640103704710    States   27 Truncation   0.000000000000
# Sweep 6 Sites 3,4    Energy -43.640103864969    States   32 Truncation   0.000572124545
# Sweep 6 Sites 4,5    Energy -43.640103987068    States   32 Truncation   0.000944594323
# Sweep 6 Sites 5,6    Energy -43.640104214256    States   32 Truncation   0.001307523673
# Sweep 6 Sites 6,7    Energy -43.640104330178    States   32 Truncation   0.001494914419
# Sweep 6 Sites 7,8    Energy -43.640104570613    States   32 Truncation   0.001752878726
# Sweep 6 Sites 8,9    Energy -43.640104686438    States   32 Truncation   0.001866137135
# Sweep 6 Sites 9,10    Energy -43.640104973551    States   32 Truncation   0.002041440521
# Sweep 6 Sites 10,11    Energy -43.640105288973    States   32 Truncation   0.002109167910
# Sweep 6 Sites 11,12    Energy -43.640105817511    States   32 Truncation   0.002212907231
# Sweep 6 Sites 12,13    Energy -43.640106822572    States   32 Truncation   0.002262234802
# Sweep 6 Sites 13,14    Energy -43.640108632108    States   32 Truncation   0.002359784274
# Sweep 6 Sites 14,15    Energy -43.640111738830    States   32 Truncation   0.002405082694
# Sweep 6 Sites 15,16    Energy -43.640116655411    States   32 Truncation   0.002502153968
# Sweep 6 Sites 16,17    Energy -43.640124256427    States   32 Truncation   0.002557229351
# Sweep 6 Sites 17,18    Energy -43.640135469395    States   32 Truncation   0.002683151284
# Sweep 6 Sites 18,19    Energy -43.640151067597    States   32 Truncation   0.002770329302
# Sweep 6 Sites 19,20    Energy -43.640169731000    States   32 Truncation   0.002958111275
# Sweep 6 Sites 20,21    Energy -43.640189404826    States   32 Truncation   0.003087575137
# Sweep 6 Sites 21,22    Energy -43.640210497233    States   32 Truncation   0.003264257440
# Sweep 6 Sites 22,23    Energy -43.640225380409    States   32 Truncation   0.003148332195
# Sweep 6 Sites 23,24    Energy -43.640237269384    States   32 Truncation   0.003112440170
# Sweep 6 Sites 24,25    Energy -43.640242687905    States   32 Truncation   0.002703482353
# Sweep 6 Sites 25,26    Energy -43.640246657744    States   32 Truncation   0.002392508732
# Sweep 6 Sites 26,27    Energy -43.640246936618    States   32 Truncation   0.001700883321
# Sweep 6 Sites 27,28    Energy -43.640246808840    States   32 Truncation   0.000951735580
# Sweep 6 Sites 28,29    Energy -43.640246350306    States   27 Truncation   0.000000000000
# Sweep 6 Sites 29,30    Energy -43.640246350307    States    9 Truncation   0.000000000000
# Sweep 7 Sites 30,31    Energy -43.640246350306    States    3 Truncation   0.000000000000
# Sweep 7 Sites 29,30    Energy -43.640246350307    States    9 Truncation   0.000000000000
# Sweep 7 Sites 28,29    Energy -43.640246350307    States   27 Truncation   0.000000000000
# Sweep 7 Sites 27,28    Energy -43.640246808840    States   32 Truncation   0.000951735580
# Sweep 7 Sites 26,27    Energy -43.640247387271    States   32 Truncation   0.001711005277
# Sweep 7 Sites 25,26    Energy -43.640248271339    States   32 Truncation   0.002409909305
# Sweep 7 Sites 24,25    Energy -43.640248635297    States   32 Truncation   0.002772606802
# Sweep 7 Sites 23,24    Energy -43.640249446884    States   32 Truncation   0.003243200982
# Sweep 7 Sites 22,23    Energy -43.640249901364    States   32 Truncation   0.003462007079
# Sweep 7 Sites 21,22    Energy -43.640250953433    States   32 Truncation   0.003756139621
# Sweep 7 Sites 20,21    Energy -43.640252490224    States   32 Truncation   0.003906395657
# Sweep 7 Sites 19,20    Energy -43.640255203864    States   32 Truncation   0.004107031110
# Sweep 7 Sites 18,19    Energy -43.640259594612    States   32 Truncation   0.004233130024
# Sweep 7 Sites 17,18    Energy -43.640266558783    States   32 Truncation   0.004407655942
# Sweep 7 Sites 16,17    Energy -43.640276877318    States   32 Truncation   0.004549186569
# Sweep 7 Sites 15,16    Energy -43.640290947291    States   32 Truncation   0.004749255428
# Sweep 7 Sites 14,15    Energy -43.640309113579    States   32 Truncation   0.004930075691
# Sweep 7 Sites 13,14    Energy -43.640331710990    States   32 Truncation   0.005196657104
# Sweep 7 Sites 12,13    Energy -43.640356660829    States   32 Truncation   0.005388432441
# Sweep 7 Sites 11,12    Energy -43.640385136332    States   32 Truncation   0.005688071581
# Sweep 7 Sites 10,11    Energy -43.640411131021    States   32 Truncation   0.005736689356
# Sweep 7 Sites 9,10    Energy -43.640439033005    States   32 Truncation   0.005888668289
# Sweep 7 Sites 8,9    Energy -43.640460054622    States   32 Truncation   0.005586820389
# Sweep 7 Sites 7,8    Energy -43.640481516545    States   32 Truncation   0.005420834754
# Sweep 7 Sites 6,7    Energy -43.640492736145    States   32 Truncation   0.004701365415
# Sweep 7 Sites 5,6    Energy -43.640503386880    States   32 Truncation   0.004106459355
# Sweep 7 Sites 4,5    Energy -43.640505575671    States   32 Truncation   0.003037220019
# Sweep 7 Sites 3,4    Energy -43.640505209257    States   32 Truncation   0.001601636775
# Sweep 7 Sites 2,3    Energy -43.640503830972    States   27 Truncation   0.000000000000
# Sweep 7 Sites 1,2    Energy -43.640503830972    States    9 Truncation   0.000000000000
# Final energy expectation value -43.640503830971895
# variance =   0.001970954492
# Integer Spin
# Sz matrix form:
#  =============
# [[-1.  0.  0.]
#  [ 0.  0.  0.]
#  [ 0.  0.  1.]]
# S+ matrix form:
#  =============
# [[0.         0.         0.        ]
#  [1.41421356 0.         0.        ]
#  [0.         1.41421356 0.        ]]
# S- matrix form:
#  =============
# [[0.         1.41421356 0.        ]
#  [0.         0.         1.41421356]
#  [0.         0.         0.        ]]
# Sweep 0 Sites 0,1    Energy -47.481194304092    States    3 Truncation   0.000000000000
# Sweep 0 Sites 1,2    Energy -47.827550196615    States    3 Truncation   0.000000000000
# Sweep 0 Sites 2,3    Energy -48.203481362554    States    3 Truncation   0.000000000000
# Sweep 0 Sites 3,4    Energy -48.567121450138    States    3 Truncation   0.000000000000
# Sweep 0 Sites 4,5    Energy -48.932138072781    States    3 Truncation   0.000000000000
# Sweep 0 Sites 5,6    Energy -49.295992885665    States    3 Truncation   0.000000000000
# Sweep 0 Sites 6,7    Energy -49.659816720597    States    3 Truncation   0.000000000000
# Sweep 0 Sites 7,8    Energy -50.023503340587    States    3 Truncation   0.000000000000
# Sweep 0 Sites 8,9    Energy -50.387163904762    States    3 Truncation   0.000000000000
# Sweep 0 Sites 9,10    Energy -50.750804560921    States    3 Truncation   0.000000000000
# Sweep 0 Sites 10,11    Energy -51.114438977516    States    3 Truncation   0.000000000000
# Sweep 0 Sites 11,12    Energy -51.478070101678    States    3 Truncation   0.000000000000
# Sweep 0 Sites 12,13    Energy -51.841699974205    States    3 Truncation   0.000000000000
# Sweep 0 Sites 13,14    Energy -52.205329266131    States    3 Truncation   0.000000000000
# Sweep 0 Sites 14,15    Energy -52.568958320115    States    3 Truncation   0.000000000000
# Sweep 0 Sites 15,16    Energy -52.932587268884    States    3 Truncation   0.000000000000
# Sweep 0 Sites 16,17    Energy -53.296216173268    States    3 Truncation   0.000000000000
# Sweep 0 Sites 17,18    Energy -53.659845058377    States    3 Truncation   0.000000000000
# Sweep 0 Sites 18,19    Energy -54.023473935263    States    3 Truncation   0.000000000000
# Sweep 0 Sites 19,20    Energy -54.387102808604    States    3 Truncation   0.000000000000
# Sweep 0 Sites 20,21    Energy -54.750731680426    States    3 Truncation   0.000000000000
# Sweep 0 Sites 21,22    Energy -55.114360551594    States    3 Truncation   0.000000000000
# Sweep 0 Sites 22,23    Energy -55.477989422482    States    3 Truncation   0.000000000000
# Sweep 0 Sites 23,24    Energy -55.841618293250    States    3 Truncation   0.000000000000
# Sweep 0 Sites 24,25    Energy -56.205247163966    States    3 Truncation   0.000000000000
# Sweep 0 Sites 25,26    Energy -56.568876034659    States    3 Truncation   0.000000000000
# Sweep 0 Sites 26,27    Energy -56.932504905344    States    3 Truncation   0.000000000000
# Sweep 0 Sites 27,28    Energy -57.296133776024    States    3 Truncation   0.000000000000
# Sweep 0 Sites 28,29    Energy -57.659762646702    States    3 Truncation   0.000000000000
# Sweep 0 Sites 29,30    Energy -58.023391517379    States    3 Truncation   0.000000000000
# Sweep 0 Sites 30,31    Energy -58.387020388057    States    3 Truncation   0.000000000000
# Sweep 0 Sites 31,32    Energy -58.750649258734    States    3 Truncation   0.000000000000
# Sweep 0 Sites 32,33    Energy -59.114278129411    States    3 Truncation   0.000000000000
# Sweep 0 Sites 33,34    Energy -59.477907000087    States    3 Truncation   0.000000000000
# Sweep 0 Sites 34,35    Energy -59.841535870764    States    3 Truncation   0.000000000000
# Sweep 0 Sites 35,36    Energy -60.205164741441    States    3 Truncation   0.000000000000
# Sweep 0 Sites 36,37    Energy -60.568793612118    States    3 Truncation   0.000000000000
# Sweep 0 Sites 37,38    Energy -60.932422482795    States    3 Truncation   0.000000000000
# Sweep 0 Sites 38,39    Energy -61.296051353472    States    3 Truncation   0.000000000000
# Sweep 0 Sites 39,40    Energy -61.659680224149    States    3 Truncation   0.000000000000
# Sweep 0 Sites 40,41    Energy -62.023309094826    States    3 Truncation   0.000000000000
# Sweep 0 Sites 41,42    Energy -62.386937965503    States    3 Truncation   0.000000000000
# Sweep 0 Sites 42,43    Energy -62.750566836180    States    3 Truncation   0.000000000000
# Sweep 0 Sites 43,44    Energy -63.114195706857    States    3 Truncation   0.000000000000
# Sweep 0 Sites 44,45    Energy -63.477824577534    States    3 Truncation   0.000000000000
# Sweep 0 Sites 45,46    Energy -63.841453448210    States    3 Truncation   0.000000000000
# Sweep 1 Sites 46,47    Energy -64.396650228090    States    3 Truncation   0.000000000000
# Sweep 1 Sites 45,46    Energy -64.437982787244    States    9 Truncation   0.000000000000
# Sweep 1 Sites 44,45    Energy -64.455922634064    States    9 Truncation   0.000000000000
# Sweep 1 Sites 43,44    Energy -64.487489226570    States    9 Truncation   0.000000000000
# Sweep 1 Sites 42,43    Energy -64.512775161471    States    9 Truncation   0.000000000000
# Sweep 1 Sites 41,42    Energy -64.542602501757    States    9 Truncation   0.000000000000
# Sweep 1 Sites 40,41    Energy -64.571229417612    States    9 Truncation   0.000000000000
# Sweep 1 Sites 39,40    Energy -64.601531230336    States    9 Truncation   0.000000000000
# Sweep 1 Sites 38,39    Energy -64.631862511696    States    9 Truncation   0.000000000000
# Sweep 1 Sites 37,38    Energy -64.662924997927    States    9 Truncation   0.000000000000
# Sweep 1 Sites 36,37    Energy -64.694221912598    States    9 Truncation   0.000000000000
# Sweep 1 Sites 35,36    Energy -64.725896233175    States    9 Truncation   0.000000000000
# Sweep 1 Sites 34,35    Energy -64.757779697919    States    9 Truncation   0.000000000000
# Sweep 1 Sites 33,34    Energy -64.789882008952    States    9 Truncation   0.000000000000
# Sweep 1 Sites 32,33    Energy -64.822135356028    States    9 Truncation   0.000000000000
# Sweep 1 Sites 31,32    Energy -64.854523923814    States    9 Truncation   0.000000000000
# Sweep 1 Sites 30,31    Energy -64.887014773201    States    9 Truncation   0.000000000000
# Sweep 1 Sites 29,30    Energy -64.919591725833    States    9 Truncation   0.000000000000
# Sweep 1 Sites 28,29    Energy -64.952236341529    States    9 Truncation   0.000000000000
# Sweep 1 Sites 27,28    Energy -64.984936519805    States    9 Truncation   0.000000000000
# Sweep 1 Sites 26,27    Energy -65.017681057458    States    9 Truncation   0.000000000000
# Sweep 1 Sites 25,26    Energy -65.050461655879    States    9 Truncation   0.000000000000
# Sweep 1 Sites 24,25    Energy -65.083271233152    States    9 Truncation   0.000000000000
# Sweep 1 Sites 23,24    Energy -65.116104271699    States    9 Truncation   0.000000000000
# Sweep 1 Sites 22,23    Energy -65.148956215247    States    9 Truncation   0.000000000000
# Sweep 1 Sites 21,22    Energy -65.181823439030    States    9 Truncation   0.000000000000
# Sweep 1 Sites 20,21    Energy -65.214702989767    States    9 Truncation   0.000000000000
# Sweep 1 Sites 19,20    Energy -65.247592498017    States    9 Truncation   0.000000000000
# Sweep 1 Sites 18,19    Energy -65.280490044739    States    9 Truncation   0.000000000000
# Sweep 1 Sites 17,18    Energy -65.313394087079    States    9 Truncation   0.000000000000
# Sweep 1 Sites 16,17    Energy -65.346303383440    States    9 Truncation   0.000000000000
# Sweep 1 Sites 15,16    Energy -65.379216946815    States    9 Truncation   0.000000000000
# Sweep 1 Sites 14,15    Energy -65.412134011167    States    9 Truncation   0.000000000000
# Sweep 1 Sites 13,14    Energy -65.445054039232    States    9 Truncation   0.000000000000
# Sweep 1 Sites 12,13    Energy -65.477976755452    States    9 Truncation   0.000000000000
# Sweep 1 Sites 11,12    Energy -65.510902419651    States    9 Truncation   0.000000000000
# Sweep 1 Sites 10,11    Energy -65.543831936156    States    9 Truncation   0.000000000000
# Sweep 1 Sites 9,10    Energy -65.576769268226    States    9 Truncation   0.000000000000
# Sweep 1 Sites 8,9    Energy -65.609719049400    States    9 Truncation   0.000000000000
# Sweep 1 Sites 7,8    Energy -65.642711352309    States    9 Truncation   0.000000000000
# Sweep 1 Sites 6,7    Energy -65.675745030982    States    9 Truncation   0.000000000000
# Sweep 1 Sites 5,6    Energy -65.709087101393    States    9 Truncation   0.000000000000
# Sweep 1 Sites 4,5    Energy -65.742342062449    States    9 Truncation   0.000000000000
# Sweep 1 Sites 3,4    Energy -65.778429223170    States    9 Truncation   0.000000000000
# Sweep 1 Sites 2,3    Energy -65.809749287690    States    9 Truncation   0.000000000000
# Sweep 1 Sites 1,2    Energy -65.881075629701    States    9 Truncation   0.000000000000
# Sweep 2 Sites 0,1    Energy -65.881075629701    States    3 Truncation   0.000000000000
# Sweep 2 Sites 1,2    Energy -65.881075629701    States    9 Truncation   0.000000000000
# Sweep 2 Sites 2,3    Energy -65.885396487581    States   27 Truncation   0.000000000000
# Sweep 2 Sites 3,4    Energy -65.886267259197    States   27 Truncation   0.000000000000
# Sweep 2 Sites 4,5    Energy -65.890004865188    States   27 Truncation   0.000000000000
# Sweep 2 Sites 5,6    Energy -65.891981755640    States   27 Truncation   0.000000000000
# Sweep 2 Sites 6,7    Energy -65.895497389371    States   27 Truncation   0.000000000000
# Sweep 2 Sites 7,8    Energy -65.898311953458    States   27 Truncation   0.000000000000
# Sweep 2 Sites 8,9    Energy -65.901922101366    States   27 Truncation   0.000000000000
# Sweep 2 Sites 9,10    Energy -65.905327240735    States   27 Truncation   0.000000000000
# Sweep 2 Sites 10,11    Energy -65.909156337220    States   27 Truncation   0.000000000000
# Sweep 2 Sites 11,12    Energy -65.912977734747    States   27 Truncation   0.000000000000
# Sweep 2 Sites 12,13    Energy -65.917039717480    States   27 Truncation   0.000000000000
# Sweep 2 Sites 13,14    Energy -65.921156270671    States   27 Truncation   0.000000000000
# Sweep 2 Sites 14,15    Energy -65.925419071236    States   27 Truncation   0.000000000000
# Sweep 2 Sites 15,16    Energy -65.929745746002    States   27 Truncation   0.000000000000
# Sweep 2 Sites 16,17    Energy -65.934166467292    States   27 Truncation   0.000000000000
# Sweep 2 Sites 17,18    Energy -65.938642705063    States   27 Truncation   0.000000000000
# Sweep 2 Sites 18,19    Energy -65.943181583996    States   27 Truncation   0.000000000000
# Sweep 2 Sites 19,20    Energy -65.947763524964    States   27 Truncation   0.000000000000
# Sweep 2 Sites 20,21    Energy -65.952387614992    States   27 Truncation   0.000000000000
# Sweep 2 Sites 21,22    Energy -65.957042764712    States   27 Truncation   0.000000000000
# Sweep 2 Sites 22,23    Energy -65.961725614156    States   27 Truncation   0.000000000000
# Sweep 2 Sites 23,24    Energy -65.966429004540    States   27 Truncation   0.000000000000
# Sweep 2 Sites 24,25    Energy -65.971148998551    States   27 Truncation   0.000000000000
# Sweep 2 Sites 25,26    Energy -65.975880198345    States   27 Truncation   0.000000000000
# Sweep 2 Sites 26,27    Energy -65.980618495683    States   27 Truncation   0.000000000000
# Sweep 2 Sites 27,28    Energy -65.985358997839    States   27 Truncation   0.000000000000
# Sweep 2 Sites 28,29    Energy -65.990097247356    States   27 Truncation   0.000000000000
# Sweep 2 Sites 29,30    Energy -65.994827801174    States   27 Truncation   0.000000000000
# Sweep 2 Sites 30,31    Energy -65.999545477658    States   27 Truncation   0.000000000000
# Sweep 2 Sites 31,32    Energy -66.004242812566    States   27 Truncation   0.000000000000
# Sweep 2 Sites 32,33    Energy -66.008913793127    States   27 Truncation   0.000000000000
# Sweep 2 Sites 33,34    Energy -66.013545722378    States   27 Truncation   0.000000000000
# Sweep 2 Sites 34,35    Energy -66.018133545555    States   27 Truncation   0.000000000000
# Sweep 2 Sites 35,36    Energy -66.022649980084    States   27 Truncation   0.000000000000
# Sweep 2 Sites 36,37    Energy -66.027101421376    States   27 Truncation   0.000000000000
# Sweep 2 Sites 37,38    Energy -66.031414337878    States   27 Truncation   0.000000000000
# Sweep 2 Sites 38,39    Energy -66.035655264254    States   27 Truncation   0.000000000000
# Sweep 2 Sites 39,40    Energy -66.039589753435    States   27 Truncation   0.000000000000
# Sweep 2 Sites 40,41    Energy -66.043569864687    States   27 Truncation   0.000000000000
# Sweep 2 Sites 41,42    Energy -66.046758782142    States   27 Truncation   0.000000000000
# Sweep 2 Sites 42,43    Energy -66.050934130995    States   27 Truncation   0.000000000000
# Sweep 2 Sites 43,44    Energy -66.052675922221    States   27 Truncation   0.000000000000
# Sweep 2 Sites 44,45    Energy -66.060525504526    States   27 Truncation   0.000000000000
# Sweep 2 Sites 45,46    Energy -66.060525504526    States    9 Truncation   0.000000000000
# Sweep 3 Sites 46,47    Energy -66.060525504526    States    3 Truncation   0.000000000000
# Sweep 3 Sites 45,46    Energy -66.060525504526    States    9 Truncation   0.000000000000
# Sweep 3 Sites 44,45    Energy -66.060525504526    States   27 Truncation   0.000000000000
# Sweep 3 Sites 43,44    Energy -66.060678296613    States   32 Truncation   0.000355861897
# Sweep 3 Sites 42,43    Energy -66.060685635165    States   32 Truncation   0.000439773671
# Sweep 3 Sites 41,42    Energy -66.060867378070    States   32 Truncation   0.000610133562
# Sweep 3 Sites 40,41    Energy -66.060883838895    States   32 Truncation   0.000619144992
# Sweep 3 Sites 39,40    Energy -66.061006741267    States   32 Truncation   0.000716012149
# Sweep 3 Sites 38,39    Energy -66.061031145240    States   32 Truncation   0.000676177537
# Sweep 3 Sites 37,38    Energy -66.061112235610    States   32 Truncation   0.000758939037
# Sweep 3 Sites 36,37    Energy -66.061143249218    States   32 Truncation   0.000672368404
# Sweep 3 Sites 35,36    Energy -66.061203248859    States   32 Truncation   0.000729884921
# Sweep 3 Sites 34,35    Energy -66.061239487593    States   32 Truncation   0.000663012247
# Sweep 3 Sites 33,34    Energy -66.061290253695    States   32 Truncation   0.000690347096
# Sweep 3 Sites 32,33    Energy -66.061330385963    States   32 Truncation   0.000649524371
# Sweep 3 Sites 31,32    Energy -66.061377813313    States   32 Truncation   0.000659029594
# Sweep 3 Sites 30,31    Energy -66.061420800294    States   32 Truncation   0.000639863801
# Sweep 3 Sites 29,30    Energy -66.061467527753    States   32 Truncation   0.000639085020
# Sweep 3 Sites 28,29    Energy -66.061512600081    States   32 Truncation   0.000632050003
# Sweep 3 Sites 27,28    Energy -66.061559675258    States   32 Truncation   0.000630497991
# Sweep 3 Sites 26,27    Energy -66.061606253135    States   32 Truncation   0.000628305215
# Sweep 3 Sites 25,26    Energy -66.061653955594    States   32 Truncation   0.000626821321
# Sweep 3 Sites 24,25    Energy -66.061701604868    States   32 Truncation   0.000625825972
# Sweep 3 Sites 23,24    Energy -66.061749907455    States   32 Truncation   0.000625134901
# Sweep 3 Sites 22,23    Energy -66.061798265915    States   32 Truncation   0.000624510215
# Sweep 3 Sites 21,22    Energy -66.061847014231    States   32 Truncation   0.000623889770
# Sweep 3 Sites 20,21    Energy -66.061895755914    States   32 Truncation   0.000623159362
# Sweep 3 Sites 19,20    Energy -66.061944742192    States   32 Truncation   0.000622396590
# Sweep 3 Sites 18,19    Energy -66.061993516235    States   32 Truncation   0.000621353918
# Sweep 3 Sites 17,18    Energy -66.062042512268    States   32 Truncation   0.000620440914
# Sweep 3 Sites 16,17    Energy -66.062090864831    States   32 Truncation   0.000619092536
# Sweep 3 Sites 15,16    Energy -66.062139699791    States   32 Truncation   0.000618563495
# ...
# Sweep 4 Sites 7,8    Energy -66.062942967361    States   32 Truncation   0.001260091129
# Sweep 4 Sites 8,9    Energy -66.062944876118    States   32 Truncation   0.001312601492
# Sweep 4 Sites 9,10    Energy -66.062945433022    States   32 Truncation   0.001347514202
# Sweep 4 Sites 10,11    Energy -66.062947188636    States   32 Truncation   0.001344038713
# Sweep 4 Sites 11,12    Energy -66.062947546564    States   32 Truncation   0.001294833540
# Sweep 4 Sites 12,13    Energy -66.062948792335    States   32 Truncation   0.001289618180
# Sweep 4 Sites 13,14    Energy -66.062949031110    States   32 Truncation   0.001233485855
# Sweep 4 Sites 14,15    Energy -66.062949792661    States   32 Truncation   0.001235120577
# Sweep 4 Sites 15,16    Energy -66.062949945575    States   32 Truncation   0.001185001425
# Sweep 4 Sites 16,17    Energy -66.062950357912    States   32 Truncation   0.001181061057
# Sweep 4 Sites 17,18    Energy -66.062950490702    States   32 Truncation   0.001146257087
# Sweep 4 Sites 18,19    Energy -66.062950747456    States   32 Truncation   0.001142337275
# Sweep 4 Sites 19,20    Energy -66.062950877843    States   32 Truncation   0.001121241275
# Sweep 4 Sites 20,21    Energy -66.062951070906    States   32 Truncation   0.001120137166
# Sweep 4 Sites 21,22    Energy -66.062951203045    States   32 Truncation   0.001108640996
# Sweep 4 Sites 22,23    Energy -66.062951371469    States   32 Truncation   0.001110044946
# Sweep 4 Sites 23,24    Energy -66.062951504841    States   32 Truncation   0.001103788048
# Sweep 4 Sites 24,25    Energy -66.062951666936    States   32 Truncation   0.001107137129
# Sweep 4 Sites 25,26    Energy -66.062951801000    States   32 Truncation   0.001103684397
# Sweep 4 Sites 26,27    Energy -66.062951971454    States   32 Truncation   0.001109017878
# Sweep 4 Sites 27,28    Energy -66.062952109191    States   32 Truncation   0.001110030320
# Sweep 4 Sites 28,29    Energy -66.062952293727    States   32 Truncation   0.001121321014
# Sweep 4 Sites 29,30    Energy -66.062952436331    States   32 Truncation   0.001128126659
# Sweep 4 Sites 30,31    Energy -66.062952686858    States   32 Truncation   0.001152354409
# Sweep 4 Sites 31,32    Energy -66.062952846795    States   32 Truncation   0.001172796337
# Sweep 4 Sites 32,33    Energy -66.062953212014    States   32 Truncation   0.001211908796
# Sweep 4 Sites 33,34    Energy -66.062953414235    States   32 Truncation   0.001243939878
# Sweep 4 Sites 34,35    Energy -66.062954048579    States   32 Truncation   0.001298013867
# Sweep 4 Sites 35,36    Energy -66.062954333232    States   32 Truncation   0.001335708827
# Sweep 4 Sites 36,37    Energy -66.062955362755    States   32 Truncation   0.001378911228
# Sweep 4 Sites 37,38    Energy -66.062955774714    States   32 Truncation   0.001418786249
# Sweep 4 Sites 38,39    Energy -66.062957136250    States   32 Truncation   0.001360901392
# Sweep 4 Sites 39,40    Energy -66.062957335866    States   32 Truncation   0.001309271743
# Sweep 4 Sites 40,41    Energy -66.062958371544    States   32 Truncation   0.001181707239
# Sweep 4 Sites 41,42    Energy -66.062958430345    States   32 Truncation   0.001058072819
# Sweep 4 Sites 42,43    Energy -66.062958649997    States   32 Truncation   0.000813872845
# Sweep 4 Sites 43,44    Energy -66.062958585906    States   32 Truncation   0.000511246630
# Sweep 4 Sites 44,45    Energy -66.062958452901    States   27 Truncation   0.000000000000
# Sweep 4 Sites 45,46    Energy -66.062958452901    States    9 Truncation   0.000000000000
# Sweep 5 Sites 46,47    Energy -66.062958452901    States    3 Truncation   0.000000000000
# Sweep 5 Sites 45,46    Energy -66.062958452901    States    9 Truncation   0.000000000000
# Sweep 5 Sites 44,45    Energy -66.062958452902    States   27 Truncation   0.000000000000
# Sweep 5 Sites 43,44    Energy -66.062958585907    States   32 Truncation   0.000511246630
# Sweep 5 Sites 42,43    Energy -66.062958673370    States   32 Truncation   0.000815600973
# Sweep 5 Sites 41,42    Energy -66.062958804855    States   32 Truncation   0.001073861447
# Sweep 5 Sites 40,41    Energy -66.062958897557    States   32 Truncation   0.001191871754
# Sweep 5 Sites 39,40    Energy -66.062959014659    States   32 Truncation   0.001339185155
# Sweep 5 Sites 38,39    Energy -66.062959077141    States   32 Truncation   0.001390258148
# Sweep 5 Sites 37,38    Energy -66.062959122058    States   32 Truncation   0.001456366174
# Sweep 5 Sites 36,37    Energy -66.062959110085    States   32 Truncation   0.001450598924
# Sweep 5 Sites 35,36    Energy -66.062959059372    States   32 Truncation   0.001429438813
# Sweep 5 Sites 34,35    Energy -66.062959021373    States   32 Truncation   0.001395867058
# Sweep 5 Sites 33,34    Energy -66.062958973067    States   32 Truncation   0.001351608185
# Sweep 5 Sites 32,33    Energy -66.062958949110    States   32 Truncation   0.001316439565
# Sweep 5 Sites 31,32    Energy -66.062958919636    States   32 Truncation   0.001276969443
# Sweep 5 Sites 30,31    Energy -66.062958904258    States   32 Truncation   0.001247278953
# Sweep 5 Sites 29,30    Energy -66.062958886521    States   32 Truncation   0.001217948612
# Sweep 5 Sites 28,29    Energy -66.062958877984    States   32 Truncation   0.001197912418
# Sweep 5 Sites 27,28    Energy -66.062958867127    States   32 Truncation   0.001179527531
# Sweep 5 Sites 26,27    Energy -66.062958863907    States   32 Truncation   0.001169596139
# Sweep 5 Sites 25,26    Energy -66.062958857725    States   32 Truncation   0.001160043600
# Sweep 5 Sites 24,25    Energy -66.062958857669    States   32 Truncation   0.001157556433
# Sweep 5 Sites 23,24    Energy -66.062958854063    States   32 Truncation   0.001153943572
# Sweep 5 Sites 22,23    Energy -66.062958856059    States   32 Truncation   0.001156741173
# Sweep 5 Sites 21,22    Energy -66.062958854207    States   32 Truncation   0.001158146529
# Sweep 5 Sites 20,21    Energy -66.062958858693    States   32 Truncation   0.001166794056
# Sweep 5 Sites 19,20    Energy -66.062958859459    States   32 Truncation   0.001175230284
# Sweep 5 Sites 18,19    Energy -66.062958868566    States   32 Truncation   0.001192689972
# Sweep 5 Sites 17,18    Energy -66.062958875013    States   32 Truncation   0.001211670437
# Sweep 5 Sites 16,17    Energy -66.062958892940    States   32 Truncation   0.001240808054
# Sweep 5 Sites 15,16    Energy -66.062958910234    States   32 Truncation   0.001271345349
# Sweep 5 Sites 14,15    Energy -66.062958943779    States   32 Truncation   0.001311275144
# Sweep 5 Sites 13,14    Energy -66.062958976984    States   32 Truncation   0.001349876220
# Sweep 5 Sites 12,13    Energy -66.062959030185    States   32 Truncation   0.001391081257
# Sweep 5 Sites 11,12    Energy -66.062959088492    States   32 Truncation   0.001435480242
# Sweep 5 Sites 10,11    Energy -66.062959155896    States   32 Truncation   0.001450187744
# Sweep 5 Sites 9,10    Energy -66.062959192780    States   32 Truncation   0.001464813684
# Sweep 5 Sites 8,9    Energy -66.062959137901    States   32 Truncation   0.001383923029
# Sweep 5 Sites 7,8    Energy -66.062959086860    States   32 Truncation   0.001343570357
# Sweep 5 Sites 6,7    Energy -66.062958970514    States   32 Truncation   0.001193177245
# Sweep 5 Sites 5,6    Energy -66.062958882999    States   32 Truncation   0.001077673027
# Sweep 5 Sites 4,5    Energy -66.062958749537    States   32 Truncation   0.000817251757
# Sweep 5 Sites 3,4    Energy -66.062958661988    States   32 Truncation   0.000512005067
# Sweep 5 Sites 2,3    Energy -66.062958528622    States   27 Truncation   0.000000000000
# Sweep 5 Sites 1,2    Energy -66.062958528622    States    9 Truncation   0.000000000000
# Sweep 6 Sites 0,1    Energy -66.062958528622    States    3 Truncation   0.000000000000
# Sweep 6 Sites 1,2    Energy -66.062958528622    States    9 Truncation   0.000000000000
# Sweep 6 Sites 2,3    Energy -66.062958528622    States   27 Truncation   0.000000000000
# Sweep 6 Sites 3,4    Energy -66.062958661987    States   32 Truncation   0.000512005067
# Sweep 6 Sites 4,5    Energy -66.062958749719    States   32 Truncation   0.000817321113
# Sweep 6 Sites 5,6    Energy -66.062958884173    States   32 Truncation   0.001078120202
# Sweep 6 Sites 6,7    Energy -66.062958974681    States   32 Truncation   0.001195832231
# Sweep 6 Sites 7,8    Energy -66.062959097959    States   32 Truncation   0.001346100294
# Sweep 6 Sites 8,9    Energy -66.062959156625    States   32 Truncation   0.001390957790
# Sweep 6 Sites 9,10    Energy -66.062959220081    States   32 Truncation   0.001463208075
# Sweep 6 Sites 10,11    Energy -66.062959186078    States   32 Truncation   0.001445484046
# Sweep 6 Sites 11,12    Energy -66.062959149448    States   32 Truncation   0.001451315283
# Sweep 6 Sites 12,13    Energy -66.062959097054    States   32 Truncation   0.001410708931
# Sweep 6 Sites 13,14    Energy -66.062959040382    States   32 Truncation   0.001367746721
# Sweep 6 Sites 14,15    Energy -66.062959008263    States   32 Truncation   0.001330515462
# Sweep 6 Sites 15,16    Energy -66.062958971095    States   32 Truncation   0.001289620273
# Sweep 6 Sites 16,17    Energy -66.062958950939    States   32 Truncation   0.001257827857
# Sweep 6 Sites 17,18    Energy -66.062958929320    States   32 Truncation   0.001226601875
# Sweep 6 Sites 18,19    Energy -66.062958919069    States   32 Truncation   0.001204843764
# Sweep 6 Sites 19,20    Energy -66.062958907255    States   32 Truncation   0.001185376906
# Sweep 6 Sites 20,21    Energy -66.062958903727    States   32 Truncation   0.001174405151
# Sweep 6 Sites 21,22    Energy -66.062958897512    States   32 Truncation   0.001164602344
# Sweep 6 Sites 22,23    Energy -66.062958897802    States   32 Truncation   0.001161767866
# Sweep 6 Sites 23,24    Energy -66.062958894614    States   32 Truncation   0.001158570375
# Sweep 6 Sites 24,25    Energy -66.062958897236    States   32 Truncation   0.001161595670
# Sweep 6 Sites 25,26    Energy -66.062958896309    States   32 Truncation   0.001164222044
# Sweep 6 Sites 26,27    Energy -66.062958901723    States   32 Truncation   0.001173804420
# Sweep 6 Sites 27,28    Energy -66.062958904248    States   32 Truncation   0.001184476325
# Sweep 6 Sites 28,29    Energy -66.062958914750    States   32 Truncation   0.001203738967
# Sweep 6 Sites 29,30    Energy -66.062958923474    States   32 Truncation   0.001225327645
# Sweep 6 Sites 30,31    Energy -66.062958943214    States   32 Truncation   0.001256664622
# Sweep 6 Sites 31,32    Energy -66.062958961182    States   32 Truncation   0.001288492240
# Sweep 6 Sites 32,33    Energy -66.062958996048    States   32 Truncation   0.001329997161
# Sweep 6 Sites 33,34    Energy -66.062959024685    States   32 Truncation   0.001366702046
# Sweep 6 Sites 34,35    Energy -66.062959079823    States   32 Truncation   0.001411672252
# Sweep 6 Sites 35,36    Energy -66.062959122247    States   32 Truncation   0.001446249486
# Sweep 6 Sites 36,37    Energy -66.062959169073    States   32 Truncation   0.001459408323
# Sweep 6 Sites 37,38    Energy -66.062959187206    States   32 Truncation   0.001464252589
# Sweep 6 Sites 38,39    Energy -66.062959127215    States   32 Truncation   0.001391378169
# Sweep 6 Sites 39,40    Energy -66.062959068152    States   32 Truncation   0.001346910167
# Sweep 6 Sites 40,41    Energy -66.062958944010    States   32 Truncation   0.001196488550
# Sweep 6 Sites 41,42    Energy -66.062958852594    States   32 Truncation   0.001078562053
# Sweep 6 Sites 42,43    Energy -66.062958717816    States   32 Truncation   0.000817554288
# Sweep 6 Sites 43,44    Energy -66.062958630007    States   32 Truncation   0.000512103162
# Sweep 6 Sites 44,45    Energy -66.062958496595    States   27 Truncation   0.000000000000
# Sweep 6 Sites 45,46    Energy -66.062958496596    States    9 Truncation   0.000000000000
# Sweep 7 Sites 46,47    Energy -66.062958496595    States    3 Truncation   0.000000000000
# Sweep 7 Sites 45,46    Energy -66.062958496595    States    9 Truncation   0.000000000000
# Sweep 7 Sites 44,45    Energy -66.062958496595    States   27 Truncation   0.000000000000
# Sweep 7 Sites 43,44    Energy -66.062958630008    States   32 Truncation   0.000512103162
# Sweep 7 Sites 42,43    Energy -66.062958717787    States   32 Truncation   0.000817560875
# Sweep 7 Sites 41,42    Energy -66.062958852597    States   32 Truncation   0.001078600191
# Sweep 7 Sites 40,41    Energy -66.062958943286    States   32 Truncation   0.001196870185
# Sweep 7 Sites 39,40    Energy -66.062959067474    States   32 Truncation   0.001347279036
# Sweep 7 Sites 38,39    Energy -66.062959125687    States   32 Truncation   0.001392119803
# Sweep 7 Sites 37,38    Energy -66.062959188972    States   32 Truncation   0.001464637272
# Sweep 7 Sites 36,37    Energy -66.062959153874    States   32 Truncation   0.001446814038
# Sweep 7 Sites 35,36    Energy -66.062959121255    States   32 Truncation   0.001454742484
# Sweep 7 Sites 34,35    Energy -66.062959070171    States   32 Truncation   0.001413844230
# Sweep 7 Sites 33,34    Energy -66.062959014206    States   32 Truncation   0.001370686821
# Sweep 7 Sites 32,33    Energy -66.062958982793    States   32 Truncation   0.001333143716
# Sweep 7 Sites 31,32    Energy -66.062958946462    States   32 Truncation   0.001291995418
# Sweep 7 Sites 30,31    Energy -66.062958926741    States   32 Truncation   0.001259702389
# Sweep 7 Sites 29,30    Energy -66.062958905848    States   32 Truncation   0.001228130616
# Sweep 7 Sites 28,29    Energy -66.062958895954    States   32 Truncation   0.001205925744
# Sweep 7 Sites 27,28    Energy -66.062958884715    States   32 Truncation   0.001186243455
# Sweep 7 Sites 26,27    Energy -66.062958881450    States   32 Truncation   0.001175038373
# Sweep 7 Sites 25,26    Energy -66.062958875588    States   32 Truncation   0.001165182488
# Sweep 7 Sites 24,25    Energy -66.062958876058    States   32 Truncation   0.001162280836
# Sweep 7 Sites 23,24    Energy -66.062958873144    States   32 Truncation   0.001159158051
# Sweep 7 Sites 22,23    Energy -66.062958875951    States   32 Truncation   0.001162251385
# Sweep 7 Sites 21,22    Energy -66.062958875354    States   32 Truncation   0.001165115844
# Sweep 7 Sites 20,21    Energy -66.062958881052    States   32 Truncation   0.001174938388
# Sweep 7 Sites 19,20    Energy -66.062958884092    States   32 Truncation   0.001186097879
# Sweep 7 Sites 18,19    Energy -66.062958895038    States   32 Truncation   0.001205755468
# Sweep 7 Sites 17,18    Energy -66.062958904569    States   32 Truncation   0.001227961994
# Sweep 7 Sites 16,17    Energy -66.062958925000    States   32 Truncation   0.001259568346
# Sweep 7 Sites 15,16    Energy -66.062958944209    States   32 Truncation   0.001291950946
# Sweep 7 Sites 14,15    Energy -66.062958979859    States   32 Truncation   0.001333163537
# Sweep 7 Sites 13,14    Energy -66.062959010641    States   32 Truncation   0.001370849807
# Sweep 7 Sites 12,13    Energy -66.062959065532    States   32 Truncation   0.001413965005
# Sweep 7 Sites 11,12    Energy -66.062959116286    States   32 Truncation   0.001455182964
# Sweep 7 Sites 10,11    Energy -66.062959146059    States   32 Truncation   0.001446688162
# Sweep 7 Sites 9,10    Energy -66.062959181334    States   32 Truncation   0.001464532938
# Sweep 7 Sites 8,9    Energy -66.062959118379    States   32 Truncation   0.001392190064
# Sweep 7 Sites 7,8    Energy -66.062959060039    States   32 Truncation   0.001347503310
# Sweep 7 Sites 6,7    Energy -66.062958935562    States   32 Truncation   0.001197026642
# Sweep 7 Sites 5,6    Energy -66.062958844698    States   32 Truncation   0.001078701490
# Sweep 7 Sites 4,5    Energy -66.062958709812    States   32 Truncation   0.000817613462
# Sweep 7 Sites 3,4    Energy -66.062958622017    States   32 Truncation   0.000512127125
# Sweep 7 Sites 2,3    Energy -66.062958488594    States   27 Truncation   0.000000000000
# Sweep 7 Sites 1,2    Energy -66.062958488594    States    9 Truncation   0.000000000000
# Final energy expectation value -66.06295848859357
# variance =   0.000121993176

# %%
plt.figure(figsize = (6,4))
for i,N in enumerate([16,32,48]):
    plt.plot(np.arange(N-1)/N,totEE[i],'o-',label = f"L = {N}, mm = 32")

plt.legend()
plt.xlabel(r'$\frac{L_{system}}{L}$',fontsize = 14)
plt.ylabel('second order Renyi Entropy')
plt.show()
# plt.savefig("Sz_correlation_measurement")
plt.close()


# plt.figure(figsize = (6,4))
# for i,N in enumerate([16,32,48]):
#   x = np.arange(N-1)#/N
#   n = len(x) // 2
#   x = x[:n] + 1
#   x = np.log(N / np.pi * np.sin(np.pi / N * x))
#   y = totEE[i]
#   y = y[:n]
#   plt.plot(x, y, 'o-', label = f"L = {N}")
# x = np.arange(0,2.8,0.01)
# y = 1/8 * x+0.11
# plt.plot(x,y, label = r'$y = \frac{1}{8}x + c$')
# plt.legend()
# plt.xlabel(r'$\ln(\frac{L}{\pi}\sin(\frac{\pi}{L}L_{system}))$',fontsize = 14)
# plt.ylabel('second order Renyi Entropy')
